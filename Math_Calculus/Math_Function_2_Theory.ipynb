# %% [markdown]
# ## Müxtəlif Funksiyalar

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Şəkilləri yükləyin
img11 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_11.jpg')
img12 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_12.jpg')
img13 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_13.jpg')
img14 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_14.jpg')
img15 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_15.jpg')
img16 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_16.jpg')
img17 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_17.jpg')
img18 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_18.jpg')
img19 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_19.jpg')
img20 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_20.jpg')
img21 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_21.jpg')
img22 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_22.jpg')
img23 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_23.jpg')
img24 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_24.jpg')
img25 = Image.open(r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Muxtelif_funksiayalar_25.jpg')


# Resized şəkilləri bir siyahıya əlavə edin
image_list = [img11, img12, img13, img14, img15, img16, img17, img18, img19, img20, img21, img22, img23, img24, img25]

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
