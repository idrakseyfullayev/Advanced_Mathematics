# %% [markdown]
# ## Təsadüfi kəmiyyət, Növləri və Paylanması

# %% [markdown]
# ## ✅ **Təsadüfi kəmiyyət (Random Variable)** nədir?
#
# > **Tərif:** Təsadüfi kəmiyyət – bir eksperimentin nəticəsinə ədədi qiymət verən funksiyadır.
#
# Məsələn: Zəri atdıqda gələn rəqəm bir təsadüfi kəmiyyətdir.
#
# ---
#
# ## 📌 Təsadüfi kəmiyyətlərin **növləri**
#
# ### 1. **Diskret təsadüfi kəmiyyət (Discrete Random Variable)**
#
# * **Kəsikli dəyərlər alır** – yəni yalnız müəyyən ədədlər ala bilər (məsələn, 0, 1, 2, ...).
# * **Misal**:
#
#   * Zərin atılması → nəticə: 1, 2, 3, 4, 5, 6
#   * Bir ailədəki uşaq sayı: 0, 1, 2, ...
#
# #### Ehtimal kütlə funksiyası (Probability Mass Function – PMF)
#
# Diskret təsadüfi kəmiyyətin ehtimalları **kütlə funksiyası** ilə verilir:
#
# $$
# P(X = x_i)
# $$
#
# Burada:
#
# * $X$ – təsadüfi kəmiyyətdir,
# * $x_i$ – ala biləcəyi dəyərlər,
# * $P(X = x_i)$ – bu dəyərin gəlmə ehtimalı.
#
# 🧠 Xüsusiyyətlər:
#
# * $0 \le P(X = x_i) \le 1$
# * $\sum P(X = x_i) = 1$
#
# ---
#
# ### 2. **Kəsilməz (davamlı) təsadüfi kəmiyyət (Continuous Random Variable)**
#
# * **Davamlı aralıqda dəyərlər ala bilər** – məsələn, \[0, 1\], $(-\infty, +\infty)$
# * **Misal**:
#
#   * İnsanların boyu: 165.2 cm, 165.25 cm, ...
#   * Bir cihazın işləmə vaxtı: 3.57 saat, 3.571 saat...
#
# #### Ehtimal sıxlığı funksiyası (Probability Density Function – PDF)
#
# Bu zaman ehtimallar sıxlıq funksiyası ilə göstərilir:
#
# $$
# f(x) \ge 0
# $$
#
# Və ehtimal bir interval üçün verilir:
#
# $$
# P(a \le X \le b) = \int_a^b f(x) dx
# $$
#
# 🧠 Xüsusiyyətlər:
#
# * $f(x) \ge 0$
# * $\int_{-\infty}^{+\infty} f(x) dx = 1$
#
# > 📌 Davamlı təsadüfi kəmiyyət üçün bir **nöqtənin ehtimalı sıfırdır**:
# >
# > $$
# > P(X = x) = 0
# > $$
#
# ---
#
# ## 📘 **Paylanma qanunu (Distribution Law)**
#
# > **Tərif:** **Paylanma qanunu** – təsadüfi kəmiyyətin ala biləcəyi bütün **mümkün dəyərləri** və onların hər birinin **başvermə ehtimalını** göstərən qanundur, eləcə də bu **ehtimalların cəmi 1-ə bərabər** olmalıdır.
#
# ### 🔹 Diskret kəmiyyət üçün:
#
# Bu, sadəcə aşağıdakı kimidir:
#
# | $$x$$ | $$P(X = x)$$ |
# | --- | ---------- |
# | 0   | 0.2        |
# | 1   | 0.5        |
# | 2   | 0.3        |
#
# Burada **paylanma qanunu** bu ehtimallar cədvəlidir.
#
# ### 🔹 Davamlı kəmiyyət üçün:
#
# Paylanma qanunu sıxlıq funksiyası ilə ifadə olunur və ehtimallar **integralla** tapılır.
#
# ---
#
# ### 📌 Qısaca tərif:
#
# > **Paylanma qanunu** – təsadüfi kəmiyyətin mümkün dəyərlərinə uyğun gələn ehtimalları təyin edən qanundur.
# > Diskret halda ehtimal cədvəli,
# > davamlı halda sıxlıq funksiyası ilə ifadə olunur.

# %% [markdown]
# ## Təsadüfi kəmiyyət, Növləri və Paylanması

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Diskret_Tesadufi_Kemiyyetler_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Təsadüfi kəmiyyət, Növləri və Paylanması', size=16)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Riyazi Gözləməsi

# %% [markdown]
# ### 📘 **Tərif (bir cümlə ilə):**
#
# > **Tərif:** Diskret təsadüfi kəmiyyətin riyazi gözləməsi – bu kəmiyyətin **mümkün qiymətləri ilə onların ehtimallarının hasilinin** cəminə deyilir.
#
# ---
#
# ### 📐 **Düstur:**
#
# Əgər $X$ diskret təsadüfi kəmiyyətdirsə və bu kəmiyyət aşağıdakı qiymətləri ala bilirsə:
#
# $$
# X = x_1, x_2, x_3, \dots, x_n
# $$
#
# və müvafiq ehtimallar:
#
# $$
# P(X = x_i) = p_i
# $$
#
# olarsa, onda riyazi gözləmə belə hesablanır:
#
# $$
# \mathbb{E}[X] = \sum_{i=1}^{n} x_i \cdot p_i
# $$
#
# ---
#
# ### 🔑 **Əsas məqamlar:**
#
# 1. **Riyazi gözləmə "orta qiymət" kimi yozula bilər**, lakin bu statistik orta yox, ehtimallar əsasında hesablanan orta dəyərdir.
#
# 2. **Əgər ehtimallar toplanıb 1 etmirsə**, bu, düzgün ehtimal paylanması deyil – yəni riyazi gözləmə tətbiq oluna bilməz.
#
# 3. Riyazi gözləmə **təcrübə çox təkrarlansa, orta nəticənin yaxınlaşacağı dəyəri** göstərir.
#
# 4. Əgər $X$ yalnız bir neçə qiymət ala bilirsə, riyazi gözləmə sadə cəmlə hesablana bilər. Məsələn:
#
#    **Misal:** Zər atılır. $X$: gələn ədəd.
#
#    $$
#    \mathbb{E}[X] = \sum_{i=1}^{6} i \cdot \frac{1}{6} = \frac{1+2+3+4+5+6}{6} = 3.5
#    $$
#
# 5. Riyazi gözləmə **lineardır**:
#
#    $$
#    \mathbb{E}[aX + b] = a\mathbb{E}[X] + b
#    $$
#
#    bu, xüsusilə alqoritmlər və statistik modellər üçün çox önəmlidir.
#
# 6. Əgər təsadüfi kəmiyyət **müsbət və ya mənfi sonsuzluğa meyllidirsə**, riyazi gözləmə **mövcud olmaya da bilər**.

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Riyazi Gözləməsi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Diskret_Tesadufi_Kemiyyetin_Riyazi_Gozlemesi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Diskret təsadüfi kəmiyyətin riyazi gözləməsi', size=14)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Riyazi Gözləmənin əsas xassələri

# %% [markdown]
# ### 1. **Xətti (linearlıq) xassəsi:**
#
# Əgər $X$ və $Y$ təsadüfi kəmiyyətlərdirsə, $a$, $b$ – sabitlərdirsə:
#
# $$
# \mathbb{E}[aX + bY] = a \cdot \mathbb{E}[X] + b \cdot \mathbb{E}[Y]
# $$
#
# > Bu, ən vacib və çox istifadə olunan xassədir. Məsələn, 3 dəfə $X$-i ölçmək və üstünə 2 əlavə etmək – nəticənin gözləməsi 3 dəfə gözləmə + 2 olur.
#
# ---
#
# ### 2. **Sabitin gözləməsi sabitin özüdür:**
#
# Əgər $c$ sabit ədəddirsə:
#
# $$
# \mathbb{E}[c] = c
# $$
#
# > Yəni, dəyişməyən bir dəyərin "orta" qiyməti onun özüdür.
#
# ---
#
# ### 3. **Sabitlə vurulan təsadüfi kəmiyyətin gözləməsi:**
#
# $$
# \mathbb{E}[a \cdot X] = a \cdot \mathbb{E}[X]
# $$
#
# > Bu da xətti xassənin xüsusi halıdır. Təsadüfi kəmiyyətə sabit vurduqda, onun gözləməsi də həmin sabitə vurulur.
#
# ---
#
# ### 4. **Toplamanın gözləməsi (qısaca):**
#
# Əgər $X_1, X_2, \dots, X_n$ təsadüfi kəmiyyətlərdirsə:
#
# $$
# \mathbb{E}\left[\sum_{i=1}^{n} X_i\right] = \sum_{i=1}^{n} \mathbb{E}[X_i]
# $$
#
# > Təsadüfi kəmiyyətlərin cəminin riyazi gözləməsi, onların gözləmələrinin cəmidir. Bu xassə **müstəqillik tələb etmir** – yəni istənilən $X_i$-lər üçün doğrudur.
#
# ---
#
# ### 5. **Əgər $X \geq 0$ (bütün mümkün qiymətləri müsbətdirsə), onda:**
#
# $$
# \mathbb{E}[X] \geq 0
# $$
#
# > Riyazi gözləmə mənfi ola bilməz, əgər bütün qiymətlər sıfır və müsbətdirsə.
#
# ---
#
# ### 6. **Monotonluq xassəsi:**
#
# Əgər $X \leq Y$ həmişə doğrudursa (yəni hər nəticədə $X(\omega) \leq Y(\omega)$), onda:
#
# $$
# \mathbb{E}[X] \leq \mathbb{E}[Y]
# $$
#
# > Bu xassə funksiyaların müqayisəsində və ehtimallarla bağlı sərhədlər tapmaqda faydalıdır.
#
# ---
#
# ### 7. **Törəmə funksiyaya tətbiq (əgər varsa):**
#
# Əgər $g(X)$ funksiyası müəyyən olunubsa:
#
# $$
# \mathbb{E}[g(X)] = \sum_x g(x) \cdot P(X = x)
# $$
#
# > Məsələn, $\mathbb{E}[X^2]$ və ya $\mathbb{E}[\log(X+1)]$ kimi hallarda istifadə olunur.

# %% [markdown]
# ## Riyazi Gözləmənin əsas xassələri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Riyazi_Gozlemenin_esas_xasseleri_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Riyazi gözləmənin əsas xassələri', size=14)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Diskret təsadüfi kəmiyyət , Paylanması, Riyazi Gözləməsi Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Dis_Tes_Kem_Paylanmasi_Riyazi_Gozlemesi_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 4):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Diskret təsadüfi kəmiyyət və Paylanması
        
        Məsələ 1: X təsadüfi kəmiyyəti paylanma qanunu ilə verilmişdir. X 2, 3, 4, 5 və onlara uyğun 
        ehtimallar 0.1, P2, 0.3, P4 ehtimalı paylanma qanunu ilə verilmişdir. P4-P2=0.2 olarsa, P2 və 
        P4 ehtimallarını tapın.  
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

    if i == 1:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Diskret təsadüfi kəmiyyətin Riyazi Gözləməsi
        
        Məsələ 2: X təsadüfi kəmiyyəti paylanma qanunu ilə verilmişdir. Burdada X 2, 3, 4, 5, Ehtimallar isə 0.2, 
        0.1, 0.3, 0.4 qiymətləri alır.  Riyazi Gözləməni tapın.
        
                      
                      Kvadrat Diskret təsadüfi kəmiyyətin Riyazi Gözləməsi 
                      
        Məsələ 3: X təsadüfi kəmiyyəti paylanma qanunu ilə verilmişdir. Burdada X 5, 6, 8, 10, Ehtimallar isə 0.2, 
        0.1, 0.4, 0.3 qiymətləri alır. X^2 təsadüfi kəmiyyəti Riyazi Gözləməsini tapın.        
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()
        
    if i == 2:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Diskret təsadüfi kəmiyyətin Riyazi Gözləməsi
        
        Məsələ 4: Asılı olmayan X və Y təsadüfi kəmiyyətlər üçün M[X] = 5, M[Y] = 4 olarsa, Z = 3X - 2Y 
        təsadüfi kəmiyyətinin Riyazi Gözləməsini tapın. M[Z] = ? .
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Dispersiyası (1)

# %% [markdown]
# ## 📘 **Dispersiyanın Tərifi:**
#
# **Dispersiya (D(X))**, təsadüfi kəmiyyətin **orta qiymətdən (riyazi gözləmədən) nə qədər sapma etdiyini** ölçür. Başqa sözlə, dispersiya **dəyərlərin yayılma ölçüsüdür**.
#
# > **Tərif:**
# > Diskret təsadüfi kəmiyyətin dispersiyası — həmin kəmiyyətin mümkün qiymətlərinin **eyni ehtimallarla riyazi gözləmədən kvadratik sapmalarının orta qiymətidir**.
#
# ---
#
# ## 📐 **Dispersiya Düsturu:**
#
# Tutaq ki, $X$ diskret təsadüfi kəmiyyətdir və onun mümkün dəyərləri $x_1, x_2, ..., x_n$, müvafiq ehtimalları isə $p_1, p_2, ..., p_n$-dir. O zaman:
#
# $$
# D(X) = \sum_{i=1}^{n} (x_i - M(X))^2 \cdot p_i
# $$
#
# Burada:
#
# * $M(X)$ — təsadüfi kəmiyyətin **riyazi gözləməsi**,
# * $x_i$ — mümkün dəyərlər,
# * $p_i$ — həmin dəyərlərin ehtimalları.
#
# ---
#
# ## ✏️ **Alternativ və daha rahat düstur:**
#
# $$
# D(X) = M(X^2) - [M(X)]^2
# $$
#
# Burada:
#
# * $M(X^2) = \sum x_i^2 \cdot p_i$ — **kvadratların riyazi gözləməsi**,
# * $[M(X)]^2$ — **riyazi gözləmənin kvadratı**.
#
# Bu düstur daha sadə və praktik şəkildə dispersiyanı hesablamağa imkan verir.
#
# ---
#
# ## 💡 **Əsas Məqamlar:**
#
# 1. **Dispersiya həmişə sıfırdan böyük və ya bərabərdir**:
#
#    * Yəni $D(X) \geq 0$.
#    * Əgər $X$ sabit (dəyişməyən) bir kəmiyyətdirsə, onda dispersiyası **0** olar.
#
# 2. **Əgər kəmiyyətə sabit əlavə edilsə (X + c)**:
#
#    $$
#    D(X + c) = D(X)
#    $$
#
#    Yəni sabit əlavə dispersiyanı dəyişmir.
#
# 3. **Əgər kəmiyyət sabitlə vurulsa (cX)**:
#
#    $$
#    D(cX) = c^2 \cdot D(X)
#    $$
#
#    Yəni dispersiya **kvadratik şəkildə dəyişir**.
#
# 4. **Dispersiya vahidi**: Əgər $X$ ölçü ilə verilirsə (məsələn, manat, sm və s.), onda dispersiyanın vahidi **kvadrat ölçüdə** olur. Məsələn, əgər $X$ manatla ölçülürsə, $D(X)$ **manat²** olacaq.
#
# ---
#
# ## ✅ **Sadə Nümunə:**
#
# Tutaq ki, $X$ təsadüfi kəmiyyəti 1, 2 və 3 dəyərlərini alır və onların ehtimalları müvafiq olaraq $0.2, 0.5, 0.3$-dür.
#
# ### 1. Riyazi gözləmə:
#
# $$
# M(X) = 1 \cdot 0.2 + 2 \cdot 0.5 + 3 \cdot 0.3 = 2.1
# $$
#
# ### 2. Kvadratların gözləməsi:
#
# $$
# M(X^2) = 1^2 \cdot 0.2 + 2^2 \cdot 0.5 + 3^2 \cdot 0.3 = 0.2 + 2.0 + 2.7 = 4.9
# $$
#
# ### 3. Dispersiya:
#
# $$
# D(X) = M(X^2) - [M(X)]^2 = 4.9 - (2.1)^2 = 4.9 - 4.41 = 0.49
# $$

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Dispersiyası (2)

# %% [markdown]
# ## 📘 **Tərif (bir cümlə ilə):**
#
# > **Tərif:** Diskret təsadüfi kəmiyyətin dispersiyası — onun qiymətlərinin **riyazi gözləmədən orta kvadrat sapmasını** göstərən ölçüdür.
#
# ---
#
# ## 📐 **Düstur:**
#
# Əgər təsadüfi kəmiyyət $X$ aşağıdakı ehtimal paylanmasına malikdirsə:
#
# $$
# X = x_1, x_2, ..., x_n \quad \text{və} \quad P(X = x_i) = p_i
# $$
#
# onda dispersiya belə hesablanır:
#
# $$
# \mathrm{Var}(X) = \mathbb{E}[(X - \mathbb{E}[X])^2] = \sum_{i=1}^{n} (x_i - \mu)^2 \cdot p_i
# $$
#
# Burada:
#
# * $\mu = \mathbb{E}[X]$ — riyazi gözləmədir.
#
# ---
#
# ### ✅ **Alternativ düstur (praktik hesablamalar üçün):**
#
# $$
# \mathrm{Var}(X) = \mathbb{E}[X^2] - (\mathbb{E}[X])^2
# $$
#
# Bu üsul çox zaman daha **sadə və sürətli** hesablama imkanı verir.
#
# ---
#
# ## 🔑 **Əsas məqamlar:**
#
# ### 1. **Dispersiya həmişə sıfırdan kiçik ola bilməz**:
#
# $$
# \mathrm{Var}(X) \geq 0
# $$
#
# Çünki kvadratlar mənfi ola bilməz.
#
# ---
#
# ### 2. **Dispersiya 0 olarsa, bu nə deməkdir?**
#
# Bu o deməkdir ki, təsadüfi kəmiyyət **dəyişmir**, yəni həmişə eyni bir qiymət alır (sabitdir).
#
# ---
#
# ### 3. **Sabitlə vurulmuş təsadüfi kəmiyyətin dispersiyası:**
#
# Əgər $a$ sabit ədəddirsə, onda:
#
# $$
# \mathrm{Var}(aX) = a^2 \cdot \mathrm{Var}(X)
# $$
#
# > Dəyişənin böyüdülməsi yayılmanı kvadrat şəkildə artırır.
#
# ---
#
# ### 4. **Sabitin əlavə olunması dispersiyanı dəyişmir:**
#
# $$
# \mathrm{Var}(X + c) = \mathrm{Var}(X)
# $$
#
# > Çünki bütün qiymətlər eyni miqdarda sürüşür, amma yayılma dəyişmir.
#
# ---
#
# ### 5. **Dispersiya xətti deyil!**
#
# Yəni bu doğru deyil:
#
# $$
# \mathrm{Var}(X + Y) \neq \mathrm{Var}(X) + \mathrm{Var}(Y)
# $$
#
# Əgər $X$ və $Y$ **müstəqildirlərsə**, **yalnız o zaman** belə yazmaq olar:
#
# $$
# \mathrm{Var}(X + Y) = \mathrm{Var}(X) + \mathrm{Var}(Y)
# $$
#
# ---
#
# ### 6. **Dispersiyanın vahidi dəyişir:**
#
# Əgər $X$-in vahidi manatdırsa, $\mathrm{Var}(X)$ **manat²** olur. Bu, onu birbaşa şərh etməyi çətinləşdirir.
#
# Ona görə çox zaman **standart sapma** istifadə olunur:
#
# $$
# \sigma(X) = \sqrt{\mathrm{Var}(X)}
# $$
#
# ---
#
# ## 🎲 **Sadə nümunə:**
#
# Tutaq ki, zər atılır.
# $X$: gələn ədəd
#
# $$
# \mathbb{E}[X] = 3.5, \quad \mathbb{E}[X^2] = \frac{1^2 + 2^2 + \dots + 6^2}{6} = \frac{91}{6}
# $$
#
# $$
# \mathrm{Var}(X) = \mathbb{E}[X^2] - (\mathbb{E}[X])^2 = \frac{91}{6} - 3.5^2 = \frac{91}{6} - 12.25 \approx 2.92
# $$

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Dispersiyasının Əsas Xassələri

# %% [markdown]
# ### 📌 1. **Dispersiya həmişə mənfi olmayan ədəddir:**
#
# $$
# D(X) \geq 0
# $$
#
# * Dispersiya heç vaxt mənfi ola bilməz.
# * Əgər $D(X) = 0$ olarsa, bu o deməkdir ki, təsadüfi kəmiyyət **dəyişmir**, yəni **sabit** bir dəyər alır.
#
# ---
#
# ### 📌 2. **Sabit ədədin dispersiyası 0-dır:**
#
# $$
# D(c) = 0 \quad \text{(c — sabit ədəd)}
# $$
#
# * Yəni dəyişməyən bir ədədin yayılma (variasiya) ölçüsü yoxdur.
#
# ---
#
# ### 📌 3. **Təsadüfi kəmiyyətə sabit əlavə ediləndə dispersiya dəyişmir:**
#
# $$
# D(X + c) = D(X)
# $$
#
# * Sabit əlavə yalnız **orta qiyməti dəyişir**, amma **yayılmanı dəyişmir**.
#
# ---
#
# ### 📌 4. **Təsadüfi kəmiyyət sabitlə vurulduqda dispersiya kvadrat şəkildə dəyişir:**
#
# $$
# D(cX) = c^2 \cdot D(X)
# $$
#
# * Burada $c$ — sabit ədəddir.
# * Məsələn, əgər $X$ 2 ilə vurularsa, dispersiyası 4 dəfə böyüyər.
#
# ---
#
# ### 📌 5. **İki təsadüfi kəmiyyətin cəminin dispersiyası** (onlar **asılı deyilsə**):
#
# $$
# D(X + Y) = D(X) + D(Y)
# $$
#
# * Bu yalnız **müstəqil təsadüfi kəmiyyətlər** üçün keçərlidir.
#
# ---
#
# ### 📌 6. **İki təsadüfi kəmiyyətin cəminin dispersiyası (ümumi hal):**
#
# $$
# D(X + Y) = D(X) + D(Y) + 2 \cdot \text{Cov}(X, Y)
# $$
#
# * Burada $\text{Cov}(X, Y)$ — kovariansdır (iki kəmiyyətin birgə dəyişmə ölçüsü).
# * Əgər $X$ və $Y$ **müstəqildirsə**, onda $\text{Cov}(X, Y) = 0$.
#
# ---
#
# ### 📌 7. **Dispersiya və riyazi gözləmə arasında əlaqə:**
#
# $$
# D(X) = M(X^2) - [M(X)]^2
# $$
#
# * Bu **alternativ düstur** hesablamaları asanlaşdırır.
#
# ---
#
# ## 🔔 Qısa Cədvəl (Yadda saxla)
#
# | Əməliyyat              | Dispersiya                               |
# | ---------------------- | ---------------------------------------- |
# | $$D(c)$$                 | $$0$$                                      |
# | $$D(X + c)$$             | $$D(X)$$                                   |
# | $$D(cX)$$                | $$c^2 \cdot D(X)$$                         |
# | $$D(X + Y)$$ (müstəqil)  | $$D(X) + D(Y)$$                            |
# | $$D(X + Y)$$ (ümumi hal) | $$D(X) + D(Y) + 2 \cdot \text{Cov}(X, Y)$$ |

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Dispersiyası və Əsas Xassələri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Diskret_Tesadufi_Kemiyyetin_Dispersiyasi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Diskret təsadüfi kəmiyyətin Dispersiyası və Əsas Xassələri', size=14)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Dispersiyası Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Diskret_Tesadufi_Kemiyyetin_Dispersiyasi_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 3):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Diskret təsadüfi kəmiyyətin Dispersiyası
        
        Məsələ 1: X təsadüfi kəmiyyəti paylanma qanunu ilə verilmişdir. X 5, 8 və onlara uyğun 
        ehtimallar 0.4, 0.6 verilmişdir. X təsadüfi kəmiyyətinin Dispersiyasını tapın.  
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

    if i == 1:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title(""" Diskret təsadüfi kəmiyyətin Dispersiyası
        
        Məsələ 2: Asılı olmayan X və Y təsadüfi kəmiyyətlər üçün D[X] = 4, D[Y] = 7 olarsa, Z = 2X - 3Y  təsadüfi 
        kəmiyyətinin Dispersiyasını tapın. D[Z] = ? .
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Orta Kvadratik Meyli (Standart Deviation)

# %% [markdown]
# ### 📘 **Standart Deviation nədir?**
#
# > **Standart sapma**, təsadüfi kəmiyyətin **öz orta qiymətindən nə qədər uzaqlaşdığını** ölçən statistik göstəricidir.
# **Standart sapma** — təsadüfi kəmiyyətin öz orta qiymətindən **nə qədər sapdığını** göstərən və **dispersiyanın kvadrat kökü** ilə hesablanan yayılma ölçüsüdür.
#
#
# Yəni:
#
# * Qiymətlər **orta ətrafında nə qədər yayılıb?**
# * **Yayılma (dağılım) nə qədər güclüdür?** — bunu göstərir.
#
# ---
#
# ### 📐 **Standart Deviation düsturu (diskret kəmiyyət üçün):**
#
# Tutaq ki, təsadüfi kəmiyyət $X$ mümkün dəyərləri $x_1, x_2, ..., x_n$ alır və onların ehtimalları $p_1, p_2, ..., p_n$-dir.
#
# ### Addımlar:
#
# 1. **Riyazi gözləmə**:
#
# $$
# M(X) = \sum x_i \cdot p_i
# $$
#
# 2. **Dispersiya**:
#
# $$
# D(X) = \sum (x_i - M(X))^2 \cdot p_i
# $$
#
# 3. **Standart sapma**:
#
# $$
# \sigma(X) = \sqrt{D(X)}
# $$
#
# ---
#
# ### 💡 **Sadə dildə desək:**
#
# * Dispersiya — **kvadrat sapmaların ortasıdır**,
# * Standart sapma — onun **kvadrat köküdür**,
# * Vahidi **orijinal kəmiyyətin vahidi ilə eynidir** (məs: yaş, manat, sm və s.).
#
# ---
#
# ### ✅ **Sadə nümunə ilə hesablayaq:**
#
# Tutaq ki, təsadüfi kəmiyyət $X$ aşağıdakı cədvəl üzrə verilir:
#
# | $$x_i$$ | $$p_i$$ |
# | ----- | ----- |
# | 1     | 0.2   |
# | 2     | 0.5   |
# | 4     | 0.3   |
#
# ### 1. Riyazi gözləmə:
#
# $$
# M(X) = 1 \cdot 0.2 + 2 \cdot 0.5 + 4 \cdot 0.3 = 0.2 + 1 + 1.2 = 2.4
# $$
#
# ### 2. Dispersiya:
#
# $$
# D(X) = (1 - 2.4)^2 \cdot 0.2 + (2 - 2.4)^2 \cdot 0.5 + (4 - 2.4)^2 \cdot 0.3
# $$
#
# $$
# = (1.96) \cdot 0.2 + (0.16) \cdot 0.5 + (2.56) \cdot 0.3 = 0.392 + 0.08 + 0.768 = 1.24
# $$
#
# ### 3. Standart sapma:
#
# $$
# \sigma(X) = \sqrt{1.24} \approx 1.113
# $$
#
# ---
#
# ### 📌 Əsas xassələr:
#
# 1. $\sigma(X) \geq 0$
# 2. $\sigma(X + c) = \sigma(X)$ (sabit əlavə yayılmanı dəyişmir)
# 3. $\sigma(cX) = |c| \cdot \sigma(X)$ (vurma yayılmanı dəyişir)
# 4. Eyni vahidlə ölçülür (manat, sm, yaş və s.)
#
# ---
#
# ### 🤔 Yadda saxlamaq üçün:
#
# * **Dispersiya**: dəyişmələrin kvadrat ortası
# * **Standart sapma**: onun kvadrat kökü — daha **intuitiv ölçü**

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Orta Kvadratik Meyli (Standart Deviation)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Diskret_Tesadufi_Kemiyyetin_Orta_Kvadratik_Meyli_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(8, 5))  # Şəkilin ölçüsü
    plt.title('Diskret təsadüfi kəmiyyətin Orta Kvadratik Meyli (Stdev) ', size=14)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Diskret təsadüfi kəmiyyətin Orta Kvadratik Meyli Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Diskret_Tesadufi_Kemiyyetin_OKM_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(8, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Diskret təsadüfi kəmiyyətin Orta Kvadratik Meyli
        
        Məsələ 1: X təsadüfi kəmiyyəti paylanma qanunu ilə verilmişdir. X 4, 6 və onlara uyğun 
        ehtimallar 0.3, 0.7 verilmişdir. X təsadüfi kəmiyyətinin Orta Kvadratik Meylini tapın.  
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()
