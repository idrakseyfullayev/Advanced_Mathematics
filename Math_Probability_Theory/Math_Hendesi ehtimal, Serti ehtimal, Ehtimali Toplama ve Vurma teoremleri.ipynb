# %% [markdown]
# ## Həndəsi ehtimal

# %% [markdown]
# > **Tərif:** Həndəsi ehtimal (geometrik ehtimal) – **klassik ehtimalın** daha geniş halıdır və nəticələrin **sayla deyil, uzunluq, sahə və ya həcm kimi ölçülərlə** qiymətləndirildiyi hallarda istifadə olunur.
#
# ---
#
# ## 🔷 **Həndəsi ehtimal nədir?**
#
# > **Tərif:** Bir təsadüfi hadisənin ehtimalı, onun uyğun sahəsinin bütün mümkün sahəyə olan nisbətidir:
#
# $$
# P(A) = \frac{\text{Hadisəyə uyğun ölçü (uzunluq, sahə, həcm)}}{\text{Mümkün bütün ölçü}}
# $$
#
# ---
#
# ## 📌 **Əsas anlayışlar**
#
# | Anlayış               | İzah                                                         |
# | --------------------- | ------------------------------------------------------------ |
# | **Nəticə**            | Təsadüfi təcrübənin mümkün nəticəsi.                         |
# | **Mümkün sahə**       | Hadisənin baş verə biləcəyi bütün sahə (məs: bütün kvadrat). |
# | **Tələb olunan sahə** | Hadisənin baş verdiyi hissə (məs: dairənin içi).             |
# | **Ehtimal**           | Tələb olunan sahənin bütün sahəyə nisbəti.                   |
#
# ---
#
# ## 🧮 **Əsas düstur:**
#
# ### ✅ **Həndəsi ehtimalın ümumi formulu:**
#
# $$
# P(A) = \frac{\text{Tələb olunan uzunluq / sahə / həcm}}{\text{Cəmi mümkün uzunluq / sahə / həcm}}
# $$
#
# ---
#
# ## 📘 **Misallar**
#
# ### 🔹 **1. Uzunluqla bağlı misal:**
#
# 0-dan 10-a qədər bir nöqtə təsadüfi seçilir. Bu nöqtənin 3 ilə 7 arasında olma ehtimalı:
#
# $$
# P = \frac{7 - 3}{10 - 0} = \frac{4}{10} = 0.4
# $$
#
# ---
#
# ### 🔹 **2. Sahə ilə bağlı misal:**
#
# 1×1 ölçülü kvadratın içindən təsadüfi nöqtə seçilir. Bu nöqtənin kvadrat daxilində çəkilmiş radiusu 0.5 olan dairəyə düşmə ehtimalı:
#
# $$
# P = \frac{\pi \cdot r^2}{1^2} = \frac{\pi \cdot 0.5^2}{1} = \frac{\pi}{4} \approx 0.785
# $$
#
# ---
#
# ### 🔹 **3. Həndəsi ehtimalda klassik yanaşma mümkün deyil:**
#
# Klassik ehtimalda nəticələrin **sayını** sayırıq:
#
# $$
# P = \frac{\text{Əlverişli nəticələrin sayı}}{\text{Mümkün nəticələrin sayı}}
# $$
#
# Amma hendəsi ehtimalda **ölçü** (uzunluq, sahə və s.) əsas götürülür.
#
# ---
#
# ## ✳️ Nə vaxt istifadə olunur?
#
# * Nəticələr **sonsuz saydadır** (məsələn, real ədədlər).
# * Əşyalar **fiziki ölçüyə malikdir** (məs: uzunluq, sahə, həcm).
# * Klassik ehtimal istifadə etmək **mümkün deyil**.

# %% [markdown]
# ## Həndəsi Ehtimal

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Hendesi_Ehtimal_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Həndəsi Ehtimal', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Həndəsi Ehtimal Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Hendesi_Ehtimal_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 3):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""Məsəslə 1: -3, 12 və -1, 4 parçaları ədəd oxunda verilmişdir. Təsadufi olaraq böyük parçaya 
        atılan nöqtənin kiçik parçaya düşməsi hadisəsinin ehtimalını tapın.
        
        Məsəslə 2: Uzunluğu L olan ab parçasında təsadufi qeyd olunan nöqtənin ab parçasının 
        orta nöqtəsi olması hadisəsinin ehtimalını tapın
        
        Məsəslə 3: Tərəfi 10sm olan kvadratın daxilində radiusu R = 2sm olan dairə verilmişdir. 
        Kvadrata təsadüfən atılan nöqtənin dairəyə düşməsi hadisəsinin ehtimalını tapın""")
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()
        
    if i == 1:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""Məsəslə 4: Ümumi həcmi 40,000 kub metr olan binada ölçüləri 3 metr, 4 metr, 5 metr olan 
        bir otaq var. Binaya atılan mərminin həmin otağa düşməsi hadisəsinin ehtimalını tapın.""")
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Şərti Ehtimal

# %% [markdown]
# ### 🔷 **Şərti ehtimal nədir?**
#
# > **Tərif:** **Şərti ehtimal**, bir hadisənin, **başqa bir hadisənin baş verdiyi məlum olduqdan sonra** baş vermə ehtimalıdır.
#
#
# 📘 Yəni, **"B baş veribsə, A-nın baş vermə ehtimalı nə qədərdir?"** sualına cavab verir.
#
# ---
#
# ### 🧠 **Əsas anlayışlar**
#
# | Anlayış                | İzah                                         |
# | ---------------------- | -------------------------------------------- |
# | **Hadisə A**           | Maraqlı olan hadisə (nəticə)                 |
# | **Hadisə B**           | Məlum olan hadisə (şərt kimi qəbul olunur)   |
# | **Kəsişmə $A \cap B$** | A və B hadisələrinin eyni vaxtda baş verməsi |
# | **Şərti ehtimal**      | B baş veribsə, A-nın baş vermə ehtimalı      |
#
#
# ---
#
# ### 🧮 **Əsas düstur:**
#
# $$
# \boxed{P(A \mid B) = \frac{P(A \cap B)}{P(B)}}
# \quad \text{(əgər } P(B) > 0 \text{)}
# $$
#
# 📌 Oxunuşu: “**P A şərti B**” və ya "A-nın B baş verdikdən sonra ehtimalı" və ya "B baş verəndən sonra A-nın ehtimalı".
#
# ---
#
# ### 💡 **Qeyd:**
#
# * Şərti ehtimal üçün **şərt qoyulan hadisənin ehtimalı sıfır olmamalıdır**:
#
#   $$
#   P(B) > 0
#   $$
#
# ---
#
# ### 🔁 **Əlaqəli düstur:**
#
# ### 🔹 **Kəsişmə düsturu (çarpma düsturu):**
#
# $$
# P(A \cap B) = P(A \mid B) \cdot P(B)
# $$
#
# və ya
#
# $$
# P(A \cap B) = P(B \mid A) \cdot P(A)
# $$
#
# ---
#
#
# ### 📘 **Sadə izah:**
#
# **Normal ehtimalda**: “A baş verə bilər?”
# **Şərti ehtimalda**: “B artıq baş verib, indi A-nın baş vermə şansı nə qədərdir?”
#
# ---
#
#
#
# ### 🧮 **Bayes Teoremi (əlavə):**
#
# Əgər lazım olarsa, Bayes teoremi də şərti ehtimaldan istifadə edir:
#
# $$
# \boxed{
# P(A \mid B) = \frac{P(B \mid A) \cdot P(A)}{P(B)}
# }
# $$
#
# ---
#
#
#
#
# ### 🧠 **Misal 1:**
#
# Bir sinifdə:
#
# * 10 oğlan
# * 20 qız var.
#
# 6 nəfər  eynək taxır, onlardan 4-ü qızdır.
#
# 🔹 **Sual**: Eynək taxan şagirdin **qız** olma ehtimalı nədir?
#
# Bu şərti ehtimaldır: $P(\text{qız} \mid \text{eynək})$
#
# $$
# P(\text{qız} \mid \text{eynək}) = \frac{P(\text{qız və eynək})}{P(\text{eynək})} = \frac{4/30}{6/30} = \frac{4}{6} = \boxed{\frac{2}{3}}
# $$
#
#
#
#
#
# Əla! Gəlin eyni məsələni **Bayes Teoremi** ilə həll edək.
# Yəni:
#
# > **Eynək taxan şagirdin qız olma ehtimalı nədir?**
# > Yəni: $P(\text{qız} \mid \text{eynək})$
#
# ---
#
# ### 🧠 **Misal 1:** ✅ Bayes Teoremi ilə Həll:
#
# Bayes teoremi belədir:
#
# $$
# P(A \mid B) = \frac{P(B \mid A) \cdot P(A)}{P(B)}
# $$
#
# Bu məsələ üçün:
#
# * **A = qız**
# * **B = eynək**
#
# $$
# P(\text{qız} \mid \text{eynək}) = \frac{P(\text{eynək} \mid \text{qız}) \cdot P(\text{qız})}{P(\text{eynək})}
# $$
#
#
#
# ### 🔢 Məlumatlar:
#
# * Ümumi şagird sayı: $10 + 20 = 30$
# * Qızların sayı: $20 \Rightarrow P(\text{qız}) = \frac{20}{30}$
# * Eynək taxan şagirdlərin sayı: 6 ⇒ $P(\text{eynək}) = \frac{6}{30}$
# * Qızlardan 4-ü eynək taxır ⇒ $P(\text{eynək} \mid \text{qız}) = \frac{4}{20}$
#
#
#
# ### 🔁 Əvəzləyək:
#
# $$
# P(\text{qız} \mid \text{eynək}) = \frac{\frac{4}{20} \cdot \frac{20}{30}}{\frac{6}{30}}
# $$
#
# Sadələşdirək:
#
# * Yuxarı: $\frac{4}{20} \cdot \frac{20}{30} = \frac{4}{30}$
# * Aşağı: $\frac{6}{30}$
#
# $$
# P(\text{qız} \mid \text{eynək}) = \frac{\frac{4}{30}}{\frac{6}{30}} = \frac{4}{6} = \frac{2}{3}
# $$
#
#
#
# ### ✅ Nəticə:
#
# $$
# \boxed{P(\text{qız} \mid \text{eynək}) = \frac{2}{3}}
# $$
#
# Yəni **eynək taxan bir şagirdin qız olması ehtimalı 2/3-dür**.
#
# ---
#
# ### 📘 **Misal 2:**
#
# Bir zarı atırsan. Bilsək ki, **atılan ədəd cütdür**, bu halda **onun 6 olma ehtimalı** nə qədərdir?
#
# * Cüt ədədlər: 2, 4, 6 → 3 nəticə
# * Bu nəticələrdən yalnız biri 6-dır.
#
# $$
# P(6 \mid \text{cütdür}) = \frac{1}{3}
# $$
#
#
# ### 🧮 **Düstur xatırlatması:**
#
# $$
# \boxed{P(A \mid B) = \frac{P(A \cap B)}{P(B)}}
# \quad \text{(əgər } P(B) > 0 \text{)}
# $$
#
# ---
#
# ### 📌 **Əlavə Qeyd:**
#
# * **Simmetrik deyildir**: Yəni
#
#   $$
#   P(A \mid B) \neq P(B \mid A)
#   $$
# * **Multiplikativ düstur**:
#
#   $$
#   P(A \cap B) = P(A \mid B) \cdot P(B)
#   $$
#
#
#
#
#
# ### ✅ **Nəticə olaraq:**
#
# | Başlıq         | Məzmun                                   |
# | -------------- | ---------------------------------------- |
# | Tərif          | B baş veribsə, A-nın baş vermə ehtimalı  |
# | Əsas düstur    | $P(A \mid B) = \frac{P(A \cap B)}{P(B)}$ |
# | Çarpma düsturu | $P(A \cap B) = P(A \mid B) \cdot P(B)$   |
# | Şərt           | $P(B) > 0$ olmalıdır                     |

# %% [markdown]
# ## Bayes Teoremi: Misal

# %% [markdown]
# ### 🧠 **Bayes Teoremi — Nümunə:**
#
# ### 📘 **Vəziyyət:**
#
# Bir şəhərdə:
#
# * Əhalinin **1%-i** müəyyən bir xəstəliyə yoluxub.
# * Bu xəstəliyi aşkarlayan test mövcuddur:
#
#   * **Xəstə olan** şəxsi **90% ehtimalla düzgün tapır**. (True Positive)
#   * **Sağlam olan** şəxsi **95% ehtimalla düzgün tanıyır**. (True Negative)
#
# ---
#
# ### 🔹 **Sual:**
#
# Test **müsbət çıxarsa**, həmin şəxsin **həqiqətən xəstə olma ehtimalı nə qədərdir?**
#
# Yəni bizə **$P(\text{Xəstə} \mid \text{Test+})$** lazımdır.
#
# ---
#
# ### ✳️ **Verilənləri yazırıq:**
#
# | Hadisə                  | Simvol                    | Ehtimal            |
# | ----------------------- | ------------------------- | ------------------ |
# | Şəxs xəstədir           | $$D$$                       | $$P(D) = 0.01$$      |
# | Şəxs sağlamdır          | $$\neg D$$                  | $$P(\neg D) = 0.99$$ |
# | Test müsbətdir (Test+)  | $$+$$                       | veriləcək aşağıda  |
# | Xəstə ikən test+ çıxır  | $$P(+ \mid D) = 0.90$$      |                    |
# | Sağlam ikən test+ çıxır | $$P(+ \mid \neg D) = 0.05$$ |                    |
#
# ---
#
# ### ✅ **Bayes düsturu ilə hesablayaq:**
#
# $$
# \boxed{
# P(A \mid B) = \frac{P(B \mid A) \cdot P(A)}{P(B)}
# }
# $$
#
# $$
# P(D \mid +) = \frac{P(+ \mid D) \cdot P(D)}{P(+)}
# $$
#
# Əvvəlcə **$P(+)$** tapırıq (testin ümumilikdə müsbət çıxma ehtimalı):
#
# $$
# P(+) = P(+ \mid D) \cdot P(D) + P(+ \mid \neg D) \cdot P(\neg D)
# $$
#
# $$
# = 0.90 \cdot 0.01 + 0.05 \cdot 0.99 = 0.009 + 0.0495 = 0.0585
# $$
#
# ---
#
# İndi əsas ehtimalı hesablayaq:
#
# $$
# P(D \mid +) = \frac{0.90 \cdot 0.01}{0.0585} = \frac{0.009}{0.0585} \approx \boxed{0.1538} \approx \boxed{15.4\%}
# $$
#
# ---
#
# ### 📌 **Nəticə:**
#
# Test **müsbət çıxsa belə**, şəxsin həqiqətən xəstə olma ehtimalı sadəcə **15.4%**-dir!
#
# ---
#
# ### 🔎 **Yorum:**
#
# Bu nəticə çox insan üçün təəccüblüdür. Amma səbəbi budur ki:
#
# * Xəstəlik **nadir haldır (1%)**, yəni çox adam onsuz da sağlamdır.
# * Testin səhv **sağlam insana müsbət** verməsi az da olsa (5%) çox insana təsir edir (çünki sağlam çoxdur!).

# %% [markdown]
# ## **Nə üçün cavab yalnız 15.4% çıxdı** və **nəticənin niyə təəccüblü olduğunu** sadə dillə izahı

# %% [markdown]
# ### 🔍 Sualımız nə idi?
#
# Test **müsbət** çıxarsa, **şəxsin həqiqətən xəstə olma ehtimalı nə qədərdir?**
#
# > Cavab: təxminən **15.4%**
#
# ---
#
# ### ❓ **Bəs niyə bu qədər azdır? Test müsbətdirsə, niyə 90% deyil?**
#
# ---
#
# ### Gəlin məsələyə **saylarla** baxaq ki, tam aydın olsun:
#
# Təsəvvür et:
#
# * Şəhərdə **10.000 nəfər** var.
# * Onların **1%-i** xəstədir → Yəni **100 nəfər** xəstədir, **9900 nəfər** sağlamdır.
#
# ---
#
# ### 🔬 Test necə işləyir?
#
# ### 1. **Xəstə olanlara test verək:**
#
# * 100 nəfər xəstədir.
# * Onların **90%-i testlə düzgün tutulur** → **90 nəfərdə test müsbət çıxır** (✅ **doğru müsbət**)
# * Qalan **10 nəfər xəstə olsa da, test səhvən mənfi çıxır** (❌ **yalançı mənfi**)
#
# ### 2. **Sağlam olanlara test verək:**
#
# * 9900 nəfər sağlamdır.
# * Testin **5%-i səhvən müsbət çıxır** →
#
#   $$
#   0.05 \cdot 9900 = 495 \text{ nəfərdə test səhvən müsbət çıxır} \quad (\text{❌ yalançı müsbət})
#   $$
#
# ---
#
# ### ✳️ **Cəmi müsbət çıxanlar:**
#
# * Doğrudan xəstə olanlar: **90 nəfər**
# * Sağlam olub testdə səhvən müsbət çıxanlar: **495 nəfər**
#
# > Yəni **müsbət test nəticəsi olanlar = 90 + 495 = 585 nəfər**
#
# ---
#
# ### ✅ **İndi ehtimal hesabı:**
#
# Bu 585 nəfərin **neçəsi həqiqətən xəstədir?**
#
# $$
# P(\text{xəstə} \mid \text{test+}) = \frac{90}{585} \approx 0.154 = 15.4\%
# $$
#
# ---
#
# ### 💡 **YEKUN NƏTİCƏ – Sadə dillə:**
#
# * Test **özlüyündə yaxşıdır** (xəstəni 90% tutur),
# * Amma **xəstəlik çox nadirdir** (cəmi 1% insanda var),
# * Sağlam adam **çoxdur** (9900 nəfər),
# * Bu qədər sağlamdan **cüzi faizlə səhv çıxsa belə**, **səhv nəticələrin sayı çox olur.**
#
# ---
#
# ### 🧠 Analogia:
#
# Təsəvvür et **içində 1 qara kürə və 99 ağ kürə** olan bir qutun var.
# Sən gözübağlı çəkirsən, və “bəlkə qaradır” deyən test 90% dəqiqliklə işləmir.
# Əksəriyyət ağ olduğuna görə, **səhv təxminlər** çox olur.

# %% [markdown]
# ## Ehtimal nəzəriyyəsində Asılı olmayan hadisələr

# %% [markdown]
# ### 🔷 **Asılı olmayan hadisələr nədir?**
#
# > **Tərif:** İki hadisə **bir-birinin nəticəsinə təsir etmirsə**, onlar **asılı olmayan (müstəqil) hadisələr** adlanır.
#
# ---
#
# ### 📘 **Sadə dillə:**
#
# Hadisə A baş verib ya yox — bu, Hadisə B-nin baş verib-verməməsinə **heç bir təsir etmirsə**, bu hadisələr **asılı deyillər**.
#
# ---
#
# ### 🧠 **Əsas anlayışlar**
#
# | Anlayış                  | İzah                                                     |
# | ------------------------ | -------------------------------------------------------- |
# | **Müstəqil hadisələr**   | Biri baş verdikdə o biri hadisənin ehtimalı dəyişmirsə   |
# | **Asılı hadisələr**      | Bir hadisənin baş verməsi digərinin ehtimalını dəyişirsə |
# | **Kəsişmə** ($A \cap B$) | Hər iki hadisənin eyni vaxtda baş verməsi                |
#
# ---
#
# ### 🧮 **Əsas düstur:**
#
# İki hadisə **müstəqildirsə**, onların kəsişmə ehtimalı belə hesablanır:
#
# $$
# \boxed{
# P(A \cap B) = P(A) \cdot P(B)
# }
# $$
#
# ---
#
# ### ✅ **Əgər:**
#
# $$
# P(A \cap B) = P(A) \cdot P(B)
# $$
#
# > Bu o deməkdir ki, **A və B hadisələri müstəqildir**
#
# Əks halda **asılıdırlar**.
#
# ---
#
# ### 📘 **Misal 1: Zar və sikkə**
#
# * Zar atılır: 1-dən 6-ya qədər rəqəm gəlir → Hadisə A: “4 gəlməsi”
# * Sikkə atılır → Hadisə B: “Gerb düşməsi”
#
# Bunlar **müstəqil hadisələrdir**, çünki birinin nəticəsi o birinə təsir etmir.
#
# $$
# P(A) = \frac{1}{6}, \quad P(B) = \frac{1}{2}
# \Rightarrow P(A \cap B) = \frac{1}{6} \cdot \frac{1}{2} = \frac{1}{12}
# $$
#
# ---
#
# ### 📘 **Misal 2: Asılı hadisə**
#
# Bir sinifdən 2 nəfər **seçirik** (qaytarmadan). Hadisələr:
#
# * A: 1-ci seçilən qızdır.
# * B: 2-ci seçilən qızdır.
#
# Bu hadisələr **asılıdır**, çünki 1-ci seçim 2-ci seçimə **təsir edir** (qız azalıbsa, ehtimal dəyişir).
#
#
# ### 🎓 **Həlli:**
#
# Bir sinifdə:
#
# * 10 nəfər var: 4 qız, 6 oğlan.
#
# Sinifdən **qaytarmadan** 2 nəfər seçirik:
#
# * Hadisə **A**: 1-ci seçilən **qız** olsun.
# * Hadisə **B**: 2-ci seçilən **qız** olsun.
#
# ---
#
# ### 🔷 **1. A hadisəsinin ehtimalı (1-ci seçilən qız)**
#
# Sinifdə 4 qız, 10 nəfər var:
#
# $$
# P(A) = \frac{4}{10}
# $$
#
# ---
#
# ### 🔷 **2. B hadisəsinin şərti ehtimalı:**
#
# **Şərt:** 1-ci qız seçilmişdir → yəni 1 qız artıq çıxıb, qalan 3 qız, 9 nəfər
#
# $$
# P(B \mid A) = \frac{3}{9}
# $$
#
# ---
#
# ### 🔷 **Kəsişmə ehtimalı:**
#
# Yəni **1-ci də qız, 2-ci də qız**:
#
# $$
# P(A \cap B) = P(A) \cdot P(B \mid A) = \frac{4}{10} \cdot \frac{3}{9} = \frac{12}{90} = \frac{2}{15}
# $$
#
# ---
#
# ### ✳️ **İndi müqayisə edək: müstəqil olsaydılar nə olardı?**
#
# Müstəqil olsaydılar:
#
# $$
# P(A \cap B) = P(A) \cdot P(B)
# $$
#
# Amma burada:
#
# * $P(A) = \frac{4}{10}$
# * $P(B)$ **sadəcə** $\frac{4}{10}$ **deyil**, çünki 1-ci seçimdən asılıdır.
#
# **Ona görə**:
#
# $$
# P(B) \neq \text{sabit}, \quad P(B \mid A) \neq P(B)
# $$
#
# ---
#
# ### ✅ **Nəticə:**
#
# Hadisə B-nin ehtimalı **A hadisəsindən asılı** olduğu üçün,
# **A və B hadisələri asılıdır**.
#
# ---
#
# ### 📌 **Nəticə olaraq:**
#
# | Başlıq                | Məzmun                                          |
# | --------------------- | ----------------------------------------------- |
# | Tərif                 | Bir hadisə digərinə təsir etmirsə → müstəqil    |
# | Əsas düstur           | $P(A \cap B) = P(A) \cdot P(B)$                 |
# | Müstəqillik yoxlanışı | Əgər bu düstur ödənirsə → hadisələr müstəqildir |

# %% [markdown]
# ## Şərti Ehtimal və Asılı olmayan hadisələr

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Serti_Ehtimal_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Şərti Ehtimal və Asılı olmayan hadisələr', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Şərti Ehtimal Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Serti_Ehtimal_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""Məsəslə 1: Bir qutuda 3 ağ və 4 qara kürə var. Qutudan hər dəfə bir kürə götürməklə iki 
        dəfə ardıcıl kürə çıxarılır. Çıxarılan kürələr qutuya qaytarılmır. Çıxarılıan 1-ci kürənin ağ 
        olduğunu bilərək (B hadisəsi) sonra çıxarılan kürənin qara olması (A hadisəsi) ehtimalını tapın.""")
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Ehtimalı Toplama Teoremləri

# %% [markdown]
# ### Toplama Teoremi
#
#
#
# > **Tərif:** **Toplama teoremi**, bir və ya bir neçə hadisədən **ən az birinin baş vermə ehtimalını** hesablamaq üçün istifadə olunan ehtimal qaydasıdır.
#
# > **Tərif:** **Toplama teoremi**, bir neçə hadisədən **ən az birinin baş vermə ehtimalını**, hadisələrin bir-biri ilə **kəsişib-kəsişməməsinə** görə düzgün şəkildə hesablayan ehtimal qaydasıdır.
#
#
#
#
# ### 📘 1. **Toplama Teoremi nədir?**
#
# Toplama teoremi ehtimal nəzəriyyəsində hadisələrin birlikdə və ya ayrı-ayrı baş vermə ehtimallarını hesablamaq üçün istifadə olunur. İki əsas forması var:
#
# ---
#
# ### 🔷 1-ci Toplama Teoremi (Mutually Exclusive – Qarşılıqlı istisna olan hadisələr)
#
# Əgər **A** və **B** hadisələri **eyni anda baş verə bilməzsə**, yəni **A ∩ B = Ø** (kəsişməsi yoxdur), onda:
#
# $$
# P(A \cup B) = P(A) + P(B)
# $$
#
# > Yəni: A və ya B baş versin ehtimalı = A-nın ehtimalı + B-nin ehtimalı
#
# ### 🔹 Misal:
#
# Bir qutuda 3 qırmızı, 2 yaşıl top var. Təsadüfi 1 top seçilir.
# Hadisə A: Qırmızı gəlsin.
# Hadisə B: Yaşıl gəlsin.
# A və B bir yerdə ola bilməz (bir seçimdə ya biri olur, ya o biri):
#
# $$
# P(A) = \frac{3}{5}, \quad P(B) = \frac{2}{5}
# $$
#
# $$
# P(A \cup B) = \frac{3}{5} + \frac{2}{5} = 1
# $$
#
# ---
#
# ### 🔷 2-ci Toplama Teoremi (Ümumi hal – kəsişməsi olan hadisələr)
#
# Əgər **A və B** hadisələrinin **kəsişməsi varsa**, yəni **eyni anda baş verə bilirlərsə**, onda:
#
# $$
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# $$
#
# > Kəsişmə çıxılır ki, təkrar sayılmasın.
#
# ### 🔹 Misal:
#
# Bir sinifdə 10 nəfər var: 4 nəfər qız, 6 nəfər oğlandır. 3 nəfər həm basketbol, həm futbol oynayır.
#
# - Hadisə A: Basketbol oynayan (6 nəfər)
# - Hadisə B: Futbol oynayan (5 nəfər)
# - Kəsişmə: Həm basketbol, həm futbol (3 nəfər)
#
# $$
# P(A) = \frac{6}{10}, \quad P(B) = \frac{5}{10}, \quad P(A \cap B) = \frac{3}{10}
# $$
#
# $$
# P(A \cup B) = \frac{6}{10} + \frac{5}{10} - \frac{3}{10} = \frac{8}{10} = 0.8
# $$
#
# ---
#
# ### 📌 Anlayışlar:
#
# | Termin                  | İzah                                                                  |
# | ----------------------- | --------------------------------------------------------------------- |
# | **A ∪ B**               | A və ya B hadisəsi baş verir (birlik)                                 |
# | **A ∩ B**               | A və B eyni anda baş verir (kəsişmə)                                  |
# | **Ø**                   | Boş dəst, yəni heç bir ortaq hal yoxdur                               |
# | **Mutually Exclusive**  | Qarşılıqlı istisna, eyni anda baş verə bilməzlər                      |
# | **Eyni anda baş vermə** | Hadisələr birgə ola bilər, məsələn bir insan həm tələbə, həm qadındır |

# %% [markdown]
# ## Ehtimalı Toplama teoremləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ehtimali_Top_teor_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Ehtimalı Toplama teoremləri', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Asılı olmayan hadisələrdən birinin baş verməsi ehtimalı

# %% [markdown]
# ### 📘 **Asılı və Asılı Olmayan Hadisələr**
#
# İlk öncə anlayışları fərqləndirək:
#
# | Anlayış                     | İzah                                                                 |
# | --------------------------- | -------------------------------------------------------------------- |
# | **Asılı hadisələr**         | Bir hadisənin baş verməsi digərinə təsir edir.                       |
# | **Asılı olmayan hadisələr** | Bir hadisənin baş verməsi digərinə təsir etmir. (müstəqil hadisələr) |
#
# ---
#
# ### 🔷 **Asılı olmayan hadisələr üçün:**
#
# Əgər A və B **asılı olmayan hadisələrdirsə**, onda:
#
# ### ✅ **Əgər B baş versə də, verməsə də, A-nın ehtimalı dəyişmirsə:**
#
# $$
# P(A | B) = P(A)
# $$
#
# Bu o deməkdir ki, A və B **müstəqil** (independent) hadisələrdir.
#
# ---
#
# ### 📌 **Asılı olmayan hadisələrin birlikdə baş verməsi:**
#
# Əgər A və B asılı deyilsə:
#
# $$
# P(A \cap B) = P(A) \cdot P(B)
# $$
#
# ---
#
# ### 🔷 Amma sualın əsas nöqtəsi:
#
# ### ➤ “**Asılı olmayan hadisələrdən birinin baş verməsi ehtimalı**” nədir?
#
# Əgər A və B **asılı olmayan hadisələrdirsə**, onda:
#
# $$
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# $$
#
# Və çünki:
#
# $$
# P(A \cap B) = P(A) \cdot P(B)
# $$
#
# Onda bu olur:
#
# $$
# P(A \cup B) = P(A) + P(B) - P(A) \cdot P(B)
# $$
#
# ---
#
# ### ✅ **Bu formul nəyi ifadə edir?**
#
# Bu, **iki müstəqil hadisədən ən az birinin baş verməsi ehtimalıdır**.
#
# ---
#
# ### 🔹 Misal:
#
# Tutaq ki, iki müstəqil hadisə var:
#
# * Hadisə A: Birinci zəri atanda 6 gəlsin →  $P(A) = \frac{1}{6}$
# * Hadisə B: İkinci zəri atanda 5 gəlsin →  $P(B) = \frac{1}{6}$
#
# Hadisələr müstəqildir, çünki biri digərinə təsir etmir.
#
# $$
# P(A \cup B) = \frac{1}{6} + \frac{1}{6} - \left( \frac{1}{6} \cdot \frac{1}{6} \right) = \frac{2}{6} - \frac{1}{36} = \frac{12 - 1}{36} = \frac{11}{36}
# $$
#
# ### Əsas Məğzi başa düşmək üçün nümunə cümləsi
# > **Yəni:** **ya** 1-ci 6 gəlsin, **ya** 2-ci 5 gəlsin, **ya da** hər ikisi – bu hallardan **ən az biri** baş versin ehtimalı **11/36**.
#
# ---
#
# ### 📌 Yekun Cədvəl:
#
# | Hadisələr                            | Düstur                                        |                          |             |
# | ------------------------------------ | --------------------------------------------- | ------------------------ | ----------- |
# | Asılı olmayanların **kəsişməsi**     | $$P(A \cap B) = P(A) \cdot P(B)$$               |                          |             |
# | Asılı olmayanların **birliyi**       | $$P(A \cup B) = P(A) + P(B) - P(A) \cdot P(B)$$ |                          |             |
# | **Müstəqil olduqlarının yoxlanması** | $$( P(A|B) = P(A)$$  və ya $$ P(B|A) = P(B) $$ |

# %% [markdown]
# ## Asılı olmayan hadisələrdən birinin baş verməsi ehtimalı

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ehtimali_Top_teor_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(2, 3):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Asılı olmayan hadisələrdən birinin baş verməsi ehtimalı', size=15)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Ehtimalı Vurma Teoremləri

# %% [markdown]
# ### EHTİMALI VURMA TEOREMLƏRİ
#
# >**Tərfi:** **Vurma teoremi**, iki və ya daha çox hadisənin **eyni anda baş vermə ehtimalını**, onların bir-birinə təsirindən asılı olaraq **şərti və ya müstəqil ehtimallarla** hesablama qaydasıdır.
#
#
#
#
#
# ### 📘 EHTİMALI VURMA TEOREMLƏRİ
#
# Ehtimalı vurma teoremləri əsasən **iki hadisənin kəsişməsi** (yəni **A ∩ B**) üçün ehtimalı hesablamaq üçündür.
#
# ---
#
# ### 🔷 1. Ümumi Vurma Teoremi (Asılı hadisələr üçün)
#
# Əgər **A və B hadisələri asılıdırsa**, yəni biri digərinə təsir edirsə:
#
# $$
# P(A \cap B) = P(A) \cdot P(B|A)
# $$
#
# > Burada $P(B|A)$ – A baş verəndən sonra B-nin baş vermə ehtimalıdır (şərti ehtimal).
#
# ---
#
# ### 🔹 Misal:
#
# Bir qutuda 3 ağ, 2 qara top var. Qaytarmadan 2 top çəkilir.
#
# * Hadisə A: 1-ci top ağ gəlsin.
# * Hadisə B: 2-ci top ağ gəlsin.
#
# Bu hadisələr **asılıdır**, çünki 1-ci top çıxandan sonra vəziyyət dəyişir.
#
# $$
# P(A) = \frac{3}{5}, \quad P(B|A) = \frac{2}{4}
# $$
#
# $$
# P(A \cap B) = \frac{3}{5} \cdot \frac{2}{4} = \frac{6}{20} = \frac{3}{10}
# $$
#
# ---
#
# ### 🔷 2. Müstəqil Hadisələr üçün Vurma Teoremi
#
# Əgər **A və B hadisələri bir-birindən asılı deyilsə**, yəni biri digərinə təsir etmirsə:
#
# $$
# P(A \cap B) = P(A) \cdot P(B)
# $$
#
# > Bu, daha sadə haldır və **asılı olmayan hadisələr üçün** keçərlidir.
#
# ---
#
# ### 🔹 Misal:
#
# İki ayrı zar atılır:
#
# * Hadisə A: 1-ci zərdə 6 gəlsin → $P(A) = \frac{1}{6}$
# * Hadisə B: 2-ci zərdə 5 gəlsin → $P(B) = \frac{1}{6}$
#
# $$
# P(A \cap B) = \frac{1}{6} \cdot \frac{1}{6} = \frac{1}{36}
# $$
#
# ---
#
# ### 🧠 Qaydalar və Anlayışlar
#
# | Anlayış                     | İzah                                                           |             |
# | --------------------------- | -------------------------------------------------------------- | ----------- |
# | **$$P(A \cap B)$$**           | A və B hadisələrinin **hər ikisi eyni anda** baş verir         |             |
# | **Asılı hadisələr**         | B-nin ehtimalı A baş verəndən sonra dəyişir: $$( P(B|A) )$$        |
# | **Asılı olmayan hadisələr** | B-nin ehtimalı A-ya bağlı deyil: $$( P(B|A) = P(B) )$$ |
# | **Vurma Teoremi**           | İki hadisənin birlikdə baş vermə ehtimalı üçün istifadə olunur |             |
#
# ---
#
# ### 🧮 Yekun Formullar
#
# | Hal                     | Düstur                          |      |
# | ----------------------- | ------------------------------- | ---- |
# | Asılı hadisələr         | $$( P(A \cap B) = P(A) \cdot P(B  | A) )$$ |
# | Asılı olmayan hadisələr | $$P(A \cap B) = P(A) \cdot P(B)$$ |      |
#
# ---
#
# ### 💡 Bonus: Üç və daha çox hadisə
#
# Üç hadisənin birlikdə baş verməsi:
#
# $$
# P(A \cap B \cap C) = P(A) \cdot P(B|A) \cdot P(C|A \cap B)
# $$
#
# Əgər hamısı asılı deyil (müstəqildirsə):
#
# $$
# P(A \cap B \cap C) = P(A) \cdot P(B) \cdot P(C)
# $$

# %% [markdown]
# ## Ehtimalı Vurma Teoremləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ehtimali_Vur_teor_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Ehtimalı Vurma Teoremləri', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Ehtimalı Toplama Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ehtimali_Top_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""       Ehtimalı Toplama teoremi: 
            Asılı olmayan iki hadisənin cəminin ehtimalı onların ehtimalları cəminə bərabərdir:
        
        Məsəslə 1: Atıcının 10-luğu vurması ehtimalı 0.3,  9-luğu vurması ehtimalı isə 0.6-dır. 
        Atıcının bir atəşdə ən azı 9-luğu vurması ehtimalını tapın
        
        
                        Asılı olmayan hadisələrdən heç olmasa birinin baş verməsi ehtimalı
                
        Məsəslə 2: Birinci atıcının hədəfi vurmaq ehtimalı 0.3, ikinci atıcının hədəfi vurmaq ehtimalı 0.6 olarsa, 
        onlardan heç olmasa birinin hədəfi vurmaq ehtimalını tapın.
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Ehtimalı Vurma və Toplama Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ehtimali_Vur_Top_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""       Ehtimalı Vurma teoremi: 
            Asılı olmayan üç hadisənin ehtimalı onların ehtimalları hasilinə bərabərdir:
        
        Məsəslə 3: Birinci atıcının hədəfi vurmaq ehtimalı 0.2, ikinci atıcının hədəfi vurmaq ehtimalı 0.6, 
        üçünçü atıcının hədəfi vurmaq ehtimalı 0.45 olarsa onlardan hər üçünün hədəfi vurmaq ehtimalını tapın.
        
        
        Ehtimalı Toplama teoremi
                        
        Məsəslə 4: Birinci atıcının hədəfi vurmaq ehtimalı 0.3, ikinci atıcının hədəfi vurmaq ehtimalı 0.4 olarsa, 
        onlardan yalnız birinin hədəfi vurmaq ehtimalını tapın.
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Ehtimalı Vurma Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ehtimali_Vur_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""       Ehtimalı Vurma teoremi: 
            Asılı olmayan iki hadisənin ehtimalı onların ehtimalları hasilinə bərabərdir:
        
        Məsəslə 5: Dəmir pul və Zər birlikdə atılır. Dəmir pulun gerb üzünün, Zərdə isə düşən xalın sadə ədəd 
        olması hadisəsinin ehtimalını tapın.
        
        Qeyd: 
        1) Heç olmasa birinin baş verməsi ehtimalı
        2) Asılı olmayan hadisələrdə hər ikisinin baş verməsi ehtimalı 
        3) Yalnız birinin baş verməsi ehtimalı  
        """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()
