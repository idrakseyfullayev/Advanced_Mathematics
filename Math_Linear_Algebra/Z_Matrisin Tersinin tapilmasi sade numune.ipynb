# %% [markdown]
# ## Ümumi tərs matris düsturu

# %% [markdown]
# ### ✅ Ümumi tərs matris düsturu:
#
# Əgər $A$ — $n \times n$ ölçülü kvadrat matrisdirsə və **determinantı sıfırdan fərqlidirsə** ($\det(A) \ne 0$), onda **tərs matris** belə hesablanır:
#
# $$
# A^{-1} = \frac{1}{\det(A)} \cdot \text{adj}(A)
# $$
#
# Burada:
#
# * $\det(A)$ — matrisin determinantı
# * $\text{adj}(A)$ — matrisin **adjoint**-u (yəni transpozə olunmuş kofaktor matrisi)
#
# ---
#
# ### ✅ Adjoint nədir?
#
# Adjoint matris belə hesablanır:
#
# $$
# \text{adj}(A) = \text{Cof}(A)^\top
# $$
#
# * $\text{Cof}(A)$ — **kofaktor matrisi** (hər bir elementin minor determinantı və uyğun işarə ilə)
# * $\top$ — **transpozə** deməkdir (sətirləri sütun, sütunları sətir edən əməliyyat)
#
# ---
#
# ### ✅ Tərs matris tapmaq üçün addımlar:
#
# 1. **Determinantı tap**: $\det(A)$
# 2. **Kofaktor matrisini tap**: $\text{Cof}(A)$
# 3. **Adjointi tap**: $\text{adj}(A) = \text{Cof}(A)^\top$
# 4. **Düsturu tətbiq et**:
#
#    $$
#    A^{-1} = \frac{1}{\det(A)} \cdot \text{adj}(A)
#    $$
#
# ---

# %% [markdown]
# ## 3×3 matris üçün tərs matrisin tapılması

# %% [markdown]
# ### 🔢 Verilmiş matris:
#
# $$
# A = \begin{bmatrix}
# 2 & 3 & 1 \\
# 0 & 1 & 4 \\
# 5 & 2 & 0
# \end{bmatrix}
# $$
#
# ---
#
# ### ✅ 1. Determinantı tap
#
# $$
# \det(A) = 2 \cdot \begin{vmatrix} 1 & 4 \\ 2 & 0 \end{vmatrix}
# - 3 \cdot \begin{vmatrix} 0 & 4 \\ 5 & 0 \end{vmatrix}
# + 1 \cdot \begin{vmatrix} 0 & 1 \\ 5 & 2 \end{vmatrix}
# $$
#
# Hər biri ayrıca:
#
# * $\begin{vmatrix} 1 & 4 \\ 2 & 0 \end{vmatrix} = 1 \cdot 0 - 4 \cdot 2 = -8$
# * $\begin{vmatrix} 0 & 4 \\ 5 & 0 \end{vmatrix} = 0 \cdot 0 - 4 \cdot 5 = -20$
# * $\begin{vmatrix} 0 & 1 \\ 5 & 2 \end{vmatrix} = 0 \cdot 2 - 1 \cdot 5 = -5$
#
# Hesablayaq:
#
# $$
# \det(A) = 2 \cdot (-8) - 3 \cdot (-20) + 1 \cdot (-5) = -16 + 60 - 5 = 39
# $$
#
# ✅ **Det(A) = 39** (tərs mövcuddur, çünki sıfırdan fərqlidir)
#
# ---
#
# ### ✅ 2. Kofaktor matrisi (Cof(A))
#
# Kofaktor üçün hər bir element üçün minor tapıb işarə veririk:
# İşarələr belədir:
#
# $$
# \begin{bmatrix}
# + & - & + \\
# - & + & - \\
# + & - & +
# \end{bmatrix}
# $$
#
# İndi bütün minorları hesablayaq:
#
# ### 1-ci sətrin kofaktorları:
#
# * $C_{11} = (+1) \cdot \begin{vmatrix} 1 & 4 \\ 2 & 0 \end{vmatrix} = -8$
# * $C_{12} = (-1) \cdot \begin{vmatrix} 0 & 4 \\ 5 & 0 \end{vmatrix} = +20$
# * $C_{13} = (+1) \cdot \begin{vmatrix} 0 & 1 \\ 5 & 2 \end{vmatrix} = -5$
#
# ### 2-ci sətrin kofaktorları:
#
# * $C_{21} = (-1) \cdot \begin{vmatrix} 3 & 1 \\ 2 & 0 \end{vmatrix} = - (3 \cdot 0 - 1 \cdot 2) = +2$
# * $C_{22} = (+1) \cdot \begin{vmatrix} 2 & 1 \\ 5 & 0 \end{vmatrix} = 2 \cdot 0 - 1 \cdot 5 = -5$
# * $C_{23} = (-1) \cdot \begin{vmatrix} 2 & 3 \\ 5 & 2 \end{vmatrix} = - (2 \cdot 2 - 3 \cdot 5) = - (4 - 15) = +11$
#
# ### 3-cü sətrin kofaktorları:
#
# * $C_{31} = (+1) \cdot \begin{vmatrix} 3 & 1 \\ 1 & 4 \end{vmatrix} = 3 \cdot 4 - 1 \cdot 1 = 12 - 1 = 11$
# * $C_{32} = (-1) \cdot \begin{vmatrix} 2 & 1 \\ 0 & 4 \end{vmatrix} = - (2 \cdot 4 - 1 \cdot 0) = -8$
# * $C_{33} = (+1) \cdot \begin{vmatrix} 2 & 3 \\ 0 & 1 \end{vmatrix} = 2 \cdot 1 - 3 \cdot 0 = 2$
#
# ---
#
# ### ✅ Kofaktor matrisi:
#
# $$
# \text{Cof}(A) = \begin{bmatrix}
# -8 & 20 & -5 \\
# 2 & -5 & 11 \\
# 11 & -8 & 2
# \end{bmatrix}
# $$
#
# ---
#
# ### ✅ 3. Adj(A) — kofaktorun transpozəsi:
#
# $$
# \text{adj}(A) = \text{Cof}(A)^T = \begin{bmatrix}
# -8 & 2 & 11 \\
# 20 & -5 & -8 \\
# -5 & 11 & 2
# \end{bmatrix}
# $$
#
# ---
#
# ### ✅ 4. Tərs matrisin alınması:
#
# $$
# A^{-1} = \frac{1}{\det(A)} \cdot \text{adj}(A)
# = \frac{1}{39} \cdot
# \begin{bmatrix}
# -8 & 2 & 11 \\
# 20 & -5 & -8 \\
# -5 & 11 & 2
# \end{bmatrix}
# $$
#
# ---
#
# ### ✅ Final nəticə:
#
# $$
# A^{-1} =
# \begin{bmatrix}
# \frac{-8}{39} & \frac{2}{39} & \frac{11}{39} \\
# \frac{20}{39} & \frac{-5}{39} & \frac{-8}{39} \\
# \frac{-5}{39} & \frac{11}{39} & \frac{2}{39}
# \end{bmatrix}
# $$
