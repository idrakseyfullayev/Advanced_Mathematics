# %% [markdown]
# ## Simmetrik matris (1)

# %% [markdown]
# >**Tərif:** Simmetrik matris elə bir kvadrat matrisdir ki, onun əsas diaqonalına görə simmetrik yerləşən elementləri bir-birinə bərabərdir.
#
# **Düstur:**
# $$
# a_{ij} = a_{ji}, \quad \forall i, j
# $$
#
# ---
#
# >**Tərif:** Simmetrik matris, transpozisi özünə bərabər olan kvadrat matrisdir. Yəni, $A$ matrisinin simmetrik olması üçün bu şərt ödənilməlidir:
#
# $$
# A^T = A
# $$
#
# Bu, o deməkdir ki, matrisin əsas diaqonalına görə əks tərəfdəki elementlər bir-birinə bərabərdir, yəni:
#
# $$
# a_{ij} = a_{ji}, \quad \forall i, j
# $$
#
# ### **Nümunə:**
# $$
# A =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 4 & 5 \\
# 3 & 5 & 6
# \end{bmatrix}
# $$
#
# Bu matrisin transpozunu alsaq:
# $$
# A^T =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 4 & 5 \\
# 3 & 5 & 6
# \end{bmatrix}
# $$
#
# Göründüyü kimi, $A^T = A$, yəni bu, simmetrik matrisdir.
#
# ### **Xüsusiyyətlər:**
# 1. **Simmetrik matrisin diaqonalında olan elementlər istənilən ədəd ola bilər.**
# 2. **Simmetrik matrisin kənar diaqonallardakı elementləri eyni olur** ($a_{ij} = a_{ji}$).
# 3. **Bütün simmetrik matrislərin öz vektorları həqiqi ədədlərdir** (bu xüsusiyyət kvadrat formalar və spektral nəzəriyyədə vacibdir).
# 4. **Simmetrik matris həmişə kvadrat olmalıdır** (simmetrik olma şərtini ödəmək üçün).
#
# Simmetrik matrislər xətti cəbrdə, statistik analizdə (kovariasiya matrisləri), fizika və mühəndislikdə çox geniş istifadə olunur. Əgər əlavə detallara ehtiyacın varsa, yaza bilərsən! 😊

# %% [markdown]
# ## Çəp Simmetrik Matris (Skew-Symmetric Matrix) (1)

# %% [markdown]
# ### **Çəp Simmetrik Matris (Skew-Symmetric Matrix)**
#
# >**Tərif:** Çəp simmetrik matris elə bir kvadrat matrisdir ki, onun transpozisi özünün mənfisinə bərabərdir. Yəni, əsas diaqonalına görə simmetrik yerləşən elementlər işarəcə tərsdir və əsas diaqonalındakı elementlər 0-dır.
#
# **Düstur:**
# $$
# A^T = -A
# $$
#
# Bu o deməkdir ki, matrisin bütün elementləri aşağıdakı şərti ödəməlidir:
# $$
# a_{ij} = -a_{ji}, \quad \forall i, j
# $$
#
# ### **Nümunə:**
# $$
# A =
# \begin{bmatrix}
# 0 & -2 & 3 \\
# 2 & 0 & -4 \\
# -3 & 4 & 0
# \end{bmatrix}
# $$
#
# Bu matrisin transpozunu alsaq:
# $$
# A^T =
# \begin{bmatrix}
# 0 & 2 & -3 \\
# -2 & 0 & 4 \\
# 3 & -4 & 0
# \end{bmatrix}
# $$
#
# Göründüyü kimi, $A^T = -A$, yəni bu, çəp simmetrik matrisdir.
#
# ### **Xüsusiyyətlər:**
# 1. **Bütün çəp simmetrik matrislərin əsas diaqonalındakı elementləri sıfırdır** ($a_{ii} = 0$).
# 2. **Əsas diaqonala görə simmetrik elementlər işarəcə tərsdir** ($a_{ij} = -a_{ji}$).
# 3. **Tək dərəcəli ölçüsü olan çəp simmetrik matris həmişə determinantı 0 olan təkil (singular) matrisdir**.
# 4. **Hər hansı bir həqiqi çəp simmetrik matrisin bütün öz qiymətləri ya 0-dır, ya da xalis xəyali (purely imaginary) ədədlərdir**.

# %% [markdown]
# ## Simmetrik matris və  Çəp Simmetrik Matris (Skew-Symmetric Matrix) (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Simmetrik_Cep_Matris_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Matrisin İzi (Trace of a Matrix) (1)

# %% [markdown]
# ### **Matrisin İzi (Trace of a Matrix)**
#
# >**Tərif:** Matrisin izi, onun əsas diaqonalındakı elementlərin cəmi kimi təyin olunur.
#
# **Düstur:**
# $$
# \text{tr}(A) = \sum_{i=1}^{n} a_{ii}
# $$
# Burada:
# - $A$ — $n \times n$ ölçülü kvadrat matris,
# - $a_{ii}$ — matrisin əsas diaqonalındakı elementlərdir,
# - $\text{tr}(A)$ — matrisin izidir.
#
# ### **Nümunə:**
# $$
# A =
# \begin{bmatrix}
# 2 & 4 & 1 \\
# 0 & 3 & -1 \\
# 5 & 2 & 6
# \end{bmatrix}
# $$
#
# Matrisin izi:
# $$
# \text{tr}(A) = 2 + 3 + 6 = 11
# $$
#
# ### **Xüsusiyyətlər:**
# 1. **İz xətti operatora nisbətən invariantdır:**
#    $$
#    \text{tr}(A + B) = \text{tr}(A) + \text{tr}(B)
#    $$
# 2. **Skalyar vurulma:**
#    $$
#    \text{tr}(cA) = c \text{tr}(A)
#    $$
# 3. **İz matrisin transpozisi üçün dəyişmir:**
#    $$
#    \text{tr}(A^T) = \text{tr}(A)
#    $$
# 4. **İz matrisin determinantı ilə qarışdırılmamalıdır, çünki o, diaqonal elementlərin cəmidir, determinant isə xüsusi hesablanır.**
# 5. **Matrisin izi onun öz qiymətlərinin cəminə bərabərdir:**
#    $$
#    \text{tr}(A) = \lambda_1 + \lambda_2 + \dots + \lambda_n
#    $$
#    Burada $\lambda_i$-lər matrisin öz qiymətləridir.
#
# Matrisin izi kvadratik formalar, xətti cəbr və statistik analizdə geniş istifadə olunur.

# %% [markdown]
# ## Matrisin İzi (Trace of a Matrix) (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Matris_izi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Determinantın Sətir və Sütun Elementlərinə Görə Ayrılması (Laplas Teoremi) (1)

# %% [markdown]
# ### **Determinantın Sətir və Sütun Elementlərinə Görə Ayrılması (Laplas Teoremi)**
#
# >**Tərif:** Laplas teoremi, **Determinant** - Matrisin hər hansı bir **sətirinin və ya sütununun**  bütün **elementlərinin** öz **Cəbri tamalayıcıları** hasilləri cəminə bərabərdir.
#
# ---
#
# Determinantın bir sətirə və ya bir sütuna görə ayrılması **Laplas genişlənməsi (Laplace expansion)** adlanır. Bu üsul determinantı kiçik ölçülü determinantlara parçalamağa kömək edir.
#
# #### **Düstur:**
# Bir $n \times n$ ölçülü $A$ matrisinin determinantını $i$-ci sətir və ya $j$-ci sütuna görə hesablamaq üçün:
#
# $$
# \det(A) = \sum_{j=1}^{n} (-1)^{i+j} a_{ij} M_{ij} \quad \text{(sətir üzrə)}
# $$
#
# $$
# \det(A) = \sum_{i=1}^{n} (-1)^{i+j} a_{ij} M_{ij} \quad \text{(sütun üzrə)}
# $$
#
# Burada:
# - $a_{ij}$ — seçilmiş sətir və ya sütundakı element,
# - $M_{ij}$ — həmin elementə aid **minör**, yəni $a_{ij}$-ni saxlayan sətir və sütun çıxarıldıqdan sonra qalan matrisin determinantı,
# - $(-1)^{i+j}$ — **köməkçi işarə** (alternativ işarələrdən ibarət matrisdən götürülür).
#
# ---
#
# ### **Nümunə: $3 \times 3$ matris üçün determinant hesablanması**
#
# Verilmiş olsun:
#
# $$
# A =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{bmatrix}
# $$
#
# Determinantı birinci sətirə ($i = 1$) görə açsaq:
#
# $$
# \det(A) = 1 \cdot
# \begin{vmatrix}
# 5 & 6 \\
# 8 & 9
# \end{vmatrix}
# - 2 \cdot
# \begin{vmatrix}
# 4 & 6 \\
# 7 & 9
# \end{vmatrix}
# + 3 \cdot
# \begin{vmatrix}
# 4 & 5 \\
# 7 & 8
# \end{vmatrix}
# $$
#
# İndi **kiçik determinantları** hesablayaq:
#
# $$
# \begin{vmatrix}
# 5 & 6 \\
# 8 & 9
# \end{vmatrix} = (5 \times 9 - 6 \times 8) = 45 - 48 = -3
# $$
#
# $$
# \begin{vmatrix}
# 4 & 6 \\
# 7 & 9
# \end{vmatrix} = (4 \times 9 - 6 \times 7) = 36 - 42 = -6
# $$
#
# $$
# \begin{vmatrix}
# 4 & 5 \\
# 7 & 8
# \end{vmatrix} = (4 \times 8 - 5 \times 7) = 32 - 35 = -3
# $$
#
# İndi determinantı hesablayaq:
#
# $$
# \det(A) = 1(-3) - 2(-6) + 3(-3)
# $$
#
# $$
# \det(A) = -3 + 12 - 9 = 0
# $$
#
# Nəticə:
# $$
# \det(A) = 0
# $$
#
# Bu üsul istənilən ölçülü kvadrat matris üçün tətbiq edilə bilər, sadəcə matrisin ölçüsü artdıqca hesablama daha çox vaxt aparır. **Daha böyük matrislər üçün rekursiv determinant hesablama və ya sıra reduksiya metodları (Gauss eliminasiya) daha effektivdir.**
#
# Əlavə izah istəsən, yaza bilərsən! 😊

# %% [markdown]
# ## Laplas Genişlənməsi ilə Determinantın Hesablanması (1)

# %% [markdown]
# >**Tərif:** Laplas teoremi, **Determinant** - Matrisin hər hansı bir **sətirinin və ya sütununun**  bütün **elementlərinin** öz **Cəbri tamalayıcıları** ilə hasilləri cəminə bərabərdir.
#
# ---
#
# ### **Laplas Genişlənməsi ilə Determinantın Hesablanması**
#
# Laplas genişlənməsi determinantın hesablama üsullarından biridir və istənilən ölçülü kvadrat matris üçün tətbiq edilə bilər. Bu metod, matrisin istənilən bir sətiri və ya sütunu üzrə genişlənmə aparılaraq determinantı hesablayır.
#
# ---
#
# ### **Laplas Genişlənməsi Düsturu:**
#
# Verilmiş $A$-nın $n \times n$ ölçülü kvadrat matrisi üçün determinant belə hesablanır:
#
# $$
# \text{det}(A) = \sum_{j=1}^{n} a_{ij} \cdot C_{ij}
# $$
#
# Burada:
# - $a_{ij}$: $A$-nın $i$-ci sətir və $j$-ci sütunundakı elementidir.
# - $C_{ij}$: $a_{ij}$-nin kofaktorudur, yəni:
#   $$
#   C_{ij} = (-1)^{i+j} \cdot \text{det}(A_{ij})
#   $$
# - $A_{ij}$: $A$-dan $i$-ci sətir və $j$-ci sütun çıxarılaraq alınan alt matrisdir.
#
# Hesablamanı istənilən bir sətir və ya sütun üzrə apara bilərsiniz.
#
# ---
#
# ### **Misal: Üç Tərtibli Matris**
#
# Verilmiş olsun:
# $$
# A = \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{bmatrix}
# $$
#
# **1. Birinci sətir üzrə genişlənmə aparaq ($i = 1$):**
#
# $$
# \text{det}(A) = \sum_{j=1}^{3} a_{1j} \cdot C_{1j}
# $$
#
# Bu ifadəni açırıq:
# $$
# \text{det}(A) = a_{11} \cdot C_{11} + a_{12} \cdot C_{12} + a_{13} \cdot C_{13}
# $$
#
# **2. Hər bir kofaktoru tapırıq:**
#
# - $C_{11} = (-1)^{1+1} \cdot \text{det} \begin{bmatrix} 5 & 6 \\ 8 & 9 \end{bmatrix}$
#   $$
#   C_{11} = \text{det} \begin{bmatrix} 5 & 6 \\ 8 & 9 \end{bmatrix} = (5 \cdot 9) - (6 \cdot 8) = 45 - 48 = -3
#   $$
#
# - $C_{12} = (-1)^{1+2} \cdot \text{det} \begin{bmatrix} 4 & 6 \\ 7 & 9 \end{bmatrix}$
#   $$
#   C_{12} = -1 \cdot \text{det} \begin{bmatrix} 4 & 6 \\ 7 & 9 \end{bmatrix} = - \big((4 \cdot 9) - (6 \cdot 7)\big) = - (36 - 42) = 6
#   $$
#
# - $C_{13} = (-1)^{1+3} \cdot \text{det} \begin{bmatrix} 4 & 5 \\ 7 & 8 \end{bmatrix}$
#   $$
#   C_{13} = \text{det} \begin{bmatrix} 4 & 5 \\ 7 & 8 \end{bmatrix} = (4 \cdot 8) - (5 \cdot 7) = 32 - 35 = -3
#   $$
#
# **3. Genişlənməni tətbiq edirik:**
#
# $$
# \text{det}(A) = (1 \cdot -3) + (2 \cdot 6) + (3 \cdot -3)
# $$
#
# $$
# \text{det}(A) = -3 + 12 - 9 = 0
# $$
#
# ---
#
# ### **Nəticə:**
# Bu matrisin determinanti $\text{det}(A) = 0$-dır.
# Bu halda matris tərs edilə bilməz, çünki determinant sıfırdır.

# %% [markdown]
# ## Determinantın Sətir və Sütun Elementlərinə Görə Ayrılması (Laplas Teoremi) (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Laplas_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Teorem (1)

# %% [markdown]
# > **Tərif:** Determinantın hər hansı bir sətirinin və ya sütununun bütün elementərinin başqa sətir və ya sütunun uyğun elemntlərinin Cəbri tamamlayıcıları ilə hasilləri cəmi sıfıra bərabərdir
#
# ---
#
# ## **Teoremin izahı**
# Bir **$n \times n$** tərtibli **$A$** kvadrat matrisini götürək. **$i$-ci sətirin və ya $j$-ci sütunun** elementlərini başqa sətir və ya sütunun uyğun elemntlərinin **cəbri tamamlayıcıları (cofactorları) ilə hasillərinin cəmi həmişə sıfırdır**, əgər həmin sətir və ya sütun **determinant hesablanmayan bir sətir və ya sütun seçilərsə**.
#
# Başqa sözlə, əgər $A = (a_{ij})$ matrisi varsa, aşağıdakı bərabərlik doğrudur:
#
# $$
# \sum_{k=1}^{n} a_{ik} C_{jk} = 0, \quad i \neq j
# $$
#
# və ya
#
# $$
# \sum_{k=1}^{n} a_{ki} C_{kj} = 0, \quad i \neq j
# $$
#
# Burada:
# - $C_{jk}$ — **$a_{jk}$** elementinin **cəbri tamamlayıcısıdır**.
# - $a_{ik}$ və $a_{ki}$ — müvafiq sətir və sütun elementləridir.
#
# ---
#
# ## **Sübutun məntiqi**
# 1. **Determinantın Laplas genişlənməsi** göstərir ki, bir sətir və ya sütunun elementləri ilə onların uyğun cəbri tamamlayıcılarının hasilinin **cəmi determinantı** verir.
#
#    $$
#    \sum_{k=1}^{n} a_{ik} C_{ik} = \det(A)
#    $$
#
# 2. **Əgər başqa bir sətir və ya sütun seçsək** (yəni determinant hesabladığımız sətir və ya sütun yox, başqa birini götürsək), onda bu ifadənin nəticəsi **həmişə 0 olur**.
#
#    $$
#    \sum_{k=1}^{n} a_{jk} C_{ik} = 0, \quad i \neq j
#    $$
#
# 3. **Bunun səbəbi ondan ibarətdir ki, determinant xətti ifadələrdən ibarət bir çoxhədli funksiyadır və bu funksiyanın tərkib hissələri digər sətir və sütunlar üçün linearly asılı olur.**
#
# ---
#
# Sən düz deyirsən! Əgər **bir sətirin elementlərini həmin sətirdə olmayan digər bir sətirin cəbri tamamlayıcıları ilə vursaq**, **nəticə həmişə 0 olmalıdır**. Mən isə **həmin sətirin öz elementləri ilə vurub toplamışam**, bu isə **determinantı** verir.
#
# Gəlin **düzgün şəkildə** izah edək:
#
# ---
#
# ### **Ümumi Qayda:**
# - **Bir sətirin öz elementləri öz cəbri tamamlayıcılarına vurulub toplananda determinant alınır**:
#   $$
#   \sum_{k=1}^{n} a_{ik} C_{ik} = \det(A)
#   $$
# - **Başqa bir sətirin elementləri fərqli bir sətirin cəbri tamamlayıcıları ilə vurulub toplananda 0 alınır**:
#   $$
#   \sum_{k=1}^{n} a_{jk} C_{ik} = 0, \quad (i \neq j)
#   $$
#
# ---
#
# ### **Düzgün Nümunə (3×3 Matris üçün)**
# Əvvəlki matrisimizi götürək:
#
# $$
# A =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{bmatrix}
# $$
#
# **Burada biz 1-ci sətirin elementlərini 2-ci sətirin cəbri tamamlayıcıları ilə vurub toplamalıyıq:**
#
# $$
# 1 \cdot C_{21} + 2 \cdot C_{22} + 3 \cdot C_{23}
# $$
#
# Əvvəl **2-ci sətirin cəbri tamamlayıcılarını** hesablayaq:
#
# $$
# C_{21} = (-1)^{2+1} \begin{vmatrix} 2 & 3 \\ 8 & 9 \end{vmatrix} = (-1) \cdot (2 \cdot 9 - 3 \cdot 8) = (-1) \cdot (-6) = 6
# $$
#
# $$
# C_{22} = (-1)^{2+2} \begin{vmatrix} 1 & 3 \\ 7 & 9 \end{vmatrix} = (1) \cdot (1 \cdot 9 - 3 \cdot 7) = 1 \cdot (-12) = -12
# $$
#
# $$
# C_{23} = (-1)^{2+3} \begin{vmatrix} 1 & 2 \\ 7 & 8 \end{vmatrix} = (-1) \cdot (1 \cdot 8 - 2 \cdot 7) = (-1) \cdot (-6) = 6
# $$
#
# İndi **1-ci sətirin elementləri ilə 2-ci sətirin cəbri tamamlayıcılarını vurub toplayaq**:
#
# $$
# 1 \cdot 6 + 2 \cdot (-12) + 3 \cdot 6
# $$
#
# $$
# = 6 - 24 + 18
# $$
#
# $$
# = 0
# $$
#
# ---
#
# ### **Nəticə:**
# Bunu hər hansı **i ≠ j** üçün edəndə həmişə **0 alınacaq**. Bu, determinantın əsas xassələrindən biridir və **cəbri tamamlayıcıların xassəsi** adlanır.
#
# **Sənin dediyin tam doğrudur. Mən əvvəlki nümunədə səhv etmişdim, çünki öz elementlərinə vurmuşdum!**

# %% [markdown]
# ## Teorem (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Teorem_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Eyni Tərtibli Kvadrat Matrislərin Hasilinin Determinantı (1)

# %% [markdown]
# **Eyni tərtibli kvadrat matrislərin hasilinin determinantı** haqqında xüsusi bir xüsusiyyət mövcuddur. Bu xüsusiyyət belədir:
#
# ### **Eyni Tərtibli Kvadrat Matrislərin Hasilinin Determinantı:**
#
# Əgər $A$ və $B$ **eyni tərtibli kvadrat matrislər**dirsə, o zaman bu matrislərin hasilinin determinantı aşağıdakı kimi hesablana bilər:
#
# $$
# \det(AB) = \det(A) \cdot \det(B)
# $$
#
# Bu, **eyni tərtibli kvadrat matrislər** üçün ümumi bir qaydadır və **eyni tərtib** dedikdə, həm $A$, həm də $B$ matrislərinin sətir və sütun saylarının bərabər olması nəzərdə tutulur.
#
# ### **Əgər Matrislər Eynidirsə (Yəni, $A = B$):**
#
# Əgər $A$ və $B$ matrisləri eynidirsə, yəni $A = B$, o zaman bu halda:
#
# $$
# \det(A^2) = (\det(A))^2
# $$
#
# Beləliklə, iki eyni tərtibli kvadrat matrisin hasilinin determinantı, həmin matrisin determinantının kvadratına bərabər olur.
#
# ### **Misal:**
#
# Tutaq ki, $A$ və $B$ matrisləri belədir:
#
# $$
# A =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}
# \quad \text{və} \quad
# B =
# \begin{bmatrix}
# 5 & 6 \\
# 7 & 8
# \end{bmatrix}
# $$
#
# Bu matrislərin hasilinin determinantını tapmağa çalışaq:
#
# 1. **Hasilini tapırıq:**
#
# $$
# AB =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}
# \begin{bmatrix}
# 5 & 6 \\
# 7 & 8
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \cdot 5 + 2 \cdot 7 & 1 \cdot 6 + 2 \cdot 8 \\
# 3 \cdot 5 + 4 \cdot 7 & 3 \cdot 6 + 4 \cdot 8
# \end{bmatrix}
# =
# \begin{bmatrix}
# 19 & 22 \\
# 43 & 50
# \end{bmatrix}
# $$
#
# 2. **Hasilin determinantını tapırıq:**
#
# $$
# \det(AB) = 19 \cdot 50 - 22 \cdot 43 = 950 - 946 = 4
# $$
#
# 3. **Ayrı-ayrılıqda $ \det(A) $ və $ \det(B) $-ni tapırıq:**
#
# $$
# \det(A) = 1 \cdot 4 - 2 \cdot 3 = 4 - 6 = -2
# $$
#
# $$
# \det(B) = 5 \cdot 8 - 6 \cdot 7 = 40 - 42 = -2
# $$
#
# 4. **Sonra $ \det(A) \cdot \det(B) $-ni tapırıq:**
#
# $$
# \det(A) \cdot \det(B) = (-2) \cdot (-2) = 4
# $$
#
# ### **Nəticə:**
#
# **$\det(AB) = \det(A) \cdot \det(B)$** olduğu görünür, yəni iki eyni tərtibli kvadrat matrisin hasilinin determinantı, həmin matrislərin determinantlarının hasilinə bərabərdir.

# %% [markdown]
# ## Eyni Tərtibli Kvadrat Matrislərin Hasilinin Determinantı (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Determinantlar_hasil_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Çəp Simmetrik Matrisin Determinantı (1)

# %% [markdown]
# **Çəp simmetrik matrisin determinantı** ilə əlaqədar xüsusiyyətlər belədir:
#
# ### **Çəp Simmetrik Matris:**
#
# Bir matris $A$ **çəp simmetrik** (və ya **skew-symmetric**) adlanır, əgər onun **transpozu** onun mənfi versiyasına bərabərdirsə, yəni:
#
# $$
# A^T = -A
# $$
#
# Başqa sözlə, $A$ matrisinin hər bir elementinin simmetrik qarşılıqları **mənfi** olmalıdır. Yəni,
#
# $$
# a_{ij} = -a_{ji}
# $$
#
# Belə bir matrisin nümunəsi aşağıdakı kimi ola bilər:
#
# $$
# A =
# \begin{bmatrix}
# 0 & 2 & -1 \\
# -2 & 0 & 3 \\
# 1 & -3 & 0
# \end{bmatrix}
# $$
#
# ### **Çəp Simmetrik Matrisin Determinantı:**
#
# Bir matrisin determinantı ilə bağlı **çəp simmetrik matrislərin** xüsusi bir xüsusiyyəti var. Bu xüsusiyyət belədir:
#
# - **Əgər matrisin ölçüsü** tək **(yəni, sətir və sütun sayı tək sayda)** olarsa, çəp simmetrik matrisin determinantı **mütləq sıfır** olur.
# - **Əgər matrisin ölçüsü** cüt **(yəni, sətir və sütun sayı cüt sayda)** olarsa, çəp simmetrik matrisin determinantı sıfır olmayacaq (bununla belə, determinantın müsbət və ya mənfi olması matrisin tərkibinə bağlıdır).
#
# ### **Nümunə:**
#
# Tutaq ki, bizdə **3x3 çəp simmetrik matris** var:
#
# $$
# A =
# \begin{bmatrix}
# 0 & 2 & -1 \\
# -2 & 0 & 3 \\
# 1 & -3 & 0
# \end{bmatrix}
# $$
#
# Bu matrisin determinantını hesablasaq:
#
# $$
# \det(A) = 0 \cdot \begin{vmatrix} 0 & 3 \\ -3 & 0 \end{vmatrix} - 2 \cdot \begin{vmatrix} -2 & 3 \\ 1 & 0 \end{vmatrix} + (-1) \cdot \begin{vmatrix} -2 & 0 \\ 1 & -3 \end{vmatrix}
# $$
#
# Hesablama addımlarına davam edək:
#
# $$
# \det(A) = 0 \cdot (0 - (-9)) - 2 \cdot ((-2) \cdot 0 - 3 \cdot 1) + (-1) \cdot ((-2) \cdot (-3) - 0 \cdot 1)
# $$
#
# $$
# \det(A) = 0 - 2 \cdot (-3) + (-1) \cdot (6)
# $$
#
# $$
# \det(A) = 0 + 6 - 6 = 0
# $$
#
# Bu halda çəp simmetrik matrisin determinantı **0** olur, çünki matrisin ölçüsü **təkdir (3x3)**.
#
# ### **Ümumiləşdirmə:**
#
# - **Tək ölçülü çəp simmetrik matrislərin determinantı həmişə sıfırdır.**
# - **Cüt ölçülü çəp simmetrik matrislərin determinantı sıfır olmaya bilər.**
#
# Bu xüsusiyyət çəp simmetrik matrislərin tək ölçülü hallarda həmişə sıfır determinantına malik olduğunu göstərir.

# %% [markdown]
# ## Çəp Simmetrik Matrisin Determinantı (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Cep_simmet_Mat_det_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Üçbucaq Determinantı (1)

# %% [markdown]
# **Üçbucaq determinantı**, **üçbucaq matrisinin** determinantını hesablamaq üçün xüsusi bir üsuldur. Üçbucaq matrislər (yuxarı və ya aşağı) determinantın sadə şəkildə tapılmasını təmin edir.
#
# >**Tərif:** Üçbucaq matrisinin **determinantı** onun **diaqonal elementlərinin hasilinə** bərabərdir.
#
# ### **Üçbucaq Matrisinin Determinantı:**
# Bir **3x3 üst üçbucaq** və ya **alt üçbucaq** matrisin determinantı yalnız onun diaqonal elementlərinin hasilinə bərabərdir.
#
# ### **Üçbucaq Matris:**
# Bir **üçbucaq matris** iki cür ola bilər:
# 1. **Üst üçbucaq matris (yuxarı üçbucaq)** — Alt üçbucaq sıfırdır.
# 2. **Alt üçbucaq matris (aşağı üçbucaq)** — Yuxarı üçbucaq sıfırdır.
#
# ### **Nümunələr:**
#
# #### 1. **Üst üçbucaq matrisin determinantı:**
#
# $$
# A =
# \begin{bmatrix}
# a_{11} & a_{12} & a_{13} \\
# 0 & a_{22} & a_{23} \\
# 0 & 0 & a_{33}
# \end{bmatrix}
# $$
#
# Bu matrisin determinantı yalnız **diaqonal elementlərin hasilinə** bərabərdir:
#
# $$
# \det(A) = a_{11} \cdot a_{22} \cdot a_{33}
# $$
#
# #### 2. **Alt üçbucaq matrisin determinantı:**
#
# $$
# B =
# \begin{bmatrix}
# b_{11} & 0 & 0 \\
# b_{21} & b_{22} & 0 \\
# b_{31} & b_{32} & b_{33}
# \end{bmatrix}
# $$
#
# Bu matrisin determinantı da yalnız **diaqonal elementlərin hasilinə** bərabərdir:
#
# $$
# \det(B) = b_{11} \cdot b_{22} \cdot b_{33}
# $$
#
# ### **Üçbucaq Matrisinin Determinantı Üçün Nümunə Hesablama:**
#
# #### **Üst üçbucaq matris nümunəsi:**
#
# $$
# A =
# \begin{bmatrix}
# 3 & 5 & 2 \\
# 0 & 4 & 6 \\
# 0 & 0 & 1
# \end{bmatrix}
# $$
#
# Bu matrisin determinantını hesablasaq:
#
# $$
# \det(A) = 3 \cdot 4 \cdot 1 = 12
# $$
#
# #### **Alt üçbucaq matris nümunəsi:**
#
# $$
# B =
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 3 & 1 & 0 \\
# 4 & 5 & 6
# \end{bmatrix}
# $$
#
# Bu matrisin determinantını hesablasaq:
#
# $$
# \det(B) = 2 \cdot 1 \cdot 6 = 12
# $$
#
# ### **Qısa Yekun:**
#
# - **Üçbucaq matrisinin determinantı** sadəcə **diaqonal elementlərin hasilinə** bərabərdir.

# %% [markdown]
# ## Üçbucaq Determinantı (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Ucbucaq_determinant_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Vandermonde Determinantı

# %% [markdown]
# >**Tərif:** **Vandermonde determinantı**, verilmiş $ x_1, x_2, \dots, x_n $ ədədləri ilə qurulmuş bir Vandermonde matrisinin determinantıdır və bu **determinant**, **həmin ədədlərin hər birinin fərqlərinin hasilinə bərabərdir**. Bu determinant, çoxluqlar və interpolasiya məsələlərində geniş tətbiq olunur.
#
# **Düstur**:
# $$
# \det(V) = \prod_{1 \leq i < j \leq n} (x_j - x_i)
# $$
#
# ---
#
# >**Tərif:** **Vandermonde determinantı** xüsusi bir determinantdır və bir çox tətbiq sahələrində istifadə olunur, xüsusən çoxluqlar və interpolasiya məsələlərində. **Vandermonde matrisinin determinantı, sıralı ədədlərin gücləri ilə təşkil olunan matrisin determinantını təsvir edir**.
#
# ### **Vandermonde Matrisinin Tərifi:**
#
# Bir **Vandermonde matrisinin** ümumi forması belədir:
#
# $$
# V =
# \begin{bmatrix}
# 1 & x_1 & x_1^2 & \dots & x_1^{n-1} \\
# 1 & x_2 & x_2^2 & \dots & x_2^{n-1} \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 1 & x_n & x_n^2 & \dots & x_n^{n-1}
# \end{bmatrix}
# $$
#
# Bu matrisin **determinantı** isə **günümüzdə ən çox tanınan formu** ilə belə təyin olunur:
#
# ### **Vandermonde Determinantı:**
#
# Bir **n x n** ölçülü Vandermonde matrisinin determinantı aşağıdakı şəkildə verilə bilər:
#
# $$
# \det(V) = \prod_{1 \leq i < j \leq n} (x_j - x_i)
# $$
#
# Yəni, determinant **x₁, x₂, ..., xn** ədədlərinin fərqlərinin hasilinə bərabərdir.
#
# ### **Əhəmiyyətli xüsusiyyətlər:**
#
# 1. **Əgər** Vandermonde matrisindəki **bütün xₖ-lər eyni** olarsa, determinant sıfır olacaqdır. Çünki bu halda hər hansı bir sütun digər bir sütunun bir kopyasına çevriləcəkdir.
#
# 2. **Vandermonde determinantı** sıralı ədədlərlə qurulan matrislərin determinantını hesablamağa imkan verir, bu da çoxsaylı riyazi və mühəndislik məsələlərində geniş istifadə olunur.
#
# ### **Nümunə:**
#
# Tutaq ki, **n = 3** üçün Vandermonde matrisini və onun determinantını hesablayaq:
#
# $$
# V =
# \begin{bmatrix}
# 1 & x_1 & x_1^2 \\
# 1 & x_2 & x_2^2 \\
# 1 & x_3 & x_3^2
# \end{bmatrix}
# $$
#
# Determinantını hesablayaq:
#
# $$
# \det(V) = (x_2 - x_1)(x_3 - x_1)(x_3 - x_2)
# $$
#
# Misal üçün, əgər **x₁ = 1, x₂ = 2, x₃ = 3** olduqda:
#
# $$
# \det(V) = (2 - 1)(3 - 1)(3 - 2) = 1 \cdot 2 \cdot 1 = 2
# $$
#
# Bu halda, **determinant 2** olar.
#
# ### **Ümumiləşdirmək:**
#
# **Vandermonde determinantı** sıralı ədədlərdən qurulmuş matrislərin determinantını tapmaq üçün çox faydalıdır və aşağıdakı şəkildə ümumiləşdirilə bilər:
#
# $$
# \det(V) = \prod_{1 \leq i < j \leq n} (x_j - x_i)
# $$

# %% [markdown]
# ## Vandermonde Determinantı (2)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Vandermonde_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Misallar

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Vandermonde_misal_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
