# %% [markdown]
# ## Düz Xəttin Parametrik Tənliyi

# %% [markdown]
# ## 📌 1. Tərif
#
# > **Tərif:** Düz xəttin parametrik tənliyi — düz xətt üzərindəki bütün nöqtələrin koordinatlarını **bir parametrdən** (adətən $t$-dən) asılı şəkildə ifadə edən tənliklər sistemidir.
# Yəni, əgər bizdə düz xəttin üzərində bir **başlanğıc nöqtə** və onun **istiqamət vektoru** məlumdursa, həmin düz xəttin bütün nöqtələrini parametrik şəkildə yaza bilərik.
#
# ---
#
# ## 📌 2. Əsas anlayışlar
#
# * **Nöqtə** $A(x_0, y_0)$ – düz xəttin keçdiyi istənilən bir nöqtə.
# * **İstiqamət vektoru** $\vec{v} = (a, b)$ – düz xəttin istiqamətini göstərən vektor.
# * **Parametr** $t \in \mathbb{R}$ – xətt üzərindəki nöqtələrin dəyişməsini idarə edən ədəddir.
#
# ---
#
# ## 📌 3. Düstur
#
# Düz xəttin parametrik tənliyi belə yazılır:
#
# $$
# \begin{cases}
# x = x_0 + at \\
# y = y_0 + bt
# \end{cases}
# \quad (t \in \mathbb{R})
# $$
#
# Burada:
#
# * $(x_0, y_0)$ — başlanğıc nöqtənin koordinatları,
# * $(a, b)$ — istiqamət vektoru,
# * $t$ — parametr.
#
# ---
#
# ## 📌 4. Üçölçülü məkan üçün
#
# Əgər 3D məkan (Ox, Oy, Oz) nəzərə alınsa:
#
# $$
# \begin{cases}
# x = x_0 + at \\
# y = y_0 + bt \\
# z = z_0 + ct
# \end{cases}
# \quad (t \in \mathbb{R})
# $$
#
# Burada $(a, b, c)$ – istiqamət vektoru, $(x_0, y_0, z_0)$ – düz xəttin keçdiyi nöqtədir.
#
# ---
#
# ## 📌 5. Sadə nümunə
#
# Məsələn, $A(1, 2)$ nöqtəsindən keçən və istiqamət vektoru $\vec{v} = (3, 4)$ olan düz xətt:
#
# $$
# \begin{cases}
# x = 1 + 3t \\
# y = 2 + 4t
# \end{cases}
# $$
#
# * $t = 0 $ üçün nöqtə $ (1, 2)$,
# * $t = 1 $ üçün nöqtə $ (4, 6)$,
# * $t = -1 $ üçün nöqtə $ (-2, -2)$.
#
# Beləliklə, parametr dəyişdikcə düz xəttin üzərindəki bütün nöqtələr alınır.

# %% [markdown]
# ## Düz Xəttin Parametrik Tənliyi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_parametrik_tenliyi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Düz Xəttin Parametrik Tənliyi', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Düz Xəttin Parametrik Tənliyi Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_parametrik_tenliyi_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Düz Xəttin Parametrik Tənliyi
        
        Məsələ 1: M_0 (1;0) nöqtədən keçən və S(2;-1) Vektorına paralel olan Düz Xəttin Parametrik 
        Tənliyini yazın. """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Düz Xəttin Kanonik Tənliyi

# %% [markdown]
# ## 📌 1. Tərif
#
# >**Tərif:** **Kanonik tənlik** — düz xəttin parametrik tənliyindən çıxarılan və bütün xətt üzərindəki nöqtələrin koordinatlarını birbaşa **nisbət şəklində** ifadə edən tənlikdir.
#
# Başqa sözlə, xəttin parametrik tənliyindəki $t$ parametrini aradan qaldıraraq əldə edilir.
#
# ---
#
# ## 📌 2. Düstur (2D müstəvi üçün)
#
# Əgər düz xəttin parametrik tənliyi belədirsə:
#
# $$
# \begin{cases}
# x = x_0 + at \\
# y = y_0 + bt
# \end{cases}
# $$
#
# O zaman **kanonik tənlik** belə alınır:
#
# $$
# \frac{x - x_0}{a} = \frac{y - y_0}{b}, \quad b \neq 0
# $$
#
# Burada:
#
# * $(x_0, y_0)$ — düz xəttin üzərində bir nöqtə,
# * $(a, b)$ — istiqamət vektoru.
#
# ---
#
# ## 📌 3. Nümunə
#
# Düz xətt $A(1, 2)$ nöqtəsindən keçir və istiqamət vektoru $\vec{v} = (3, 4)$-dür.
#
# **Parametrik tənlik:**
#
# $$
# \begin{cases}
# x = 1 + 3t \\
# y = 2 + 4t
# \end{cases}
# $$
#
# **Kanonik tənlik:**
#
# $$
# \frac{x - 1}{3} = \frac{y - 2}{4}
# $$

# %% [markdown]
# ## Düz Xəttin Kanonik Tənliyi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_kanonik_tenliyi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Düz Xəttin Kanonik Tənliyi', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Düz Xəttin Kanonik Tənliyi Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_kanonik_tenliyi_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 3):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(20, 2.5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Düz Xəttin Kanonik Tənliyi
        
        Məsələ 1: M_0 (4;-3) nöqtəsindən keçən və yönəldici Vektoru S(2;-1) olan Düz Xəttin Kanonik 
        Tənliyini yazın. """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

    if i == 1:
        plt.figure(figsize=(20, 3.8))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Düz Xəttin Kanonik Tənliyi
        
        Məsələ 2: M_0 (-5;2) nöqtəsindən keçən və M_1 (1;-1), M_2(3;2) nöqtələrini birləşdirən vektora
        paralel olan Düz Xəttin Kanonik Tənliyini yazın. """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Düz Xəttin Bucaq Əmsallı Tənliyi

# %% [markdown]
# Gəlin **Düz xəttin bucaq əmsallı tənliyi**ni addım-addım izah edək.
#
# ---
#
# ## 📌 1. Tərif
#
# >**Tərif:** **Bucaq əmsallı tənlik** — düz xəttin meylini (eğimini) nəzərə alaraq yazılan və xətt üzərindəki bütün nöqtələrin koordinatlarını birbaşa ifadə edən tənlikdir.
# Başqa sözlə, xəttin $x$ oxu ilə düz bucaq altında etdiyi bucaqdan istifadə edərək tərtib olunur.
#
#
# ## 📌  Tərif
#
# >**Tərif:** **Düz xəttin bucaq əmsallı tənliyi**, müstəvidə xəttin meylini göstərən sabit bucaq əmsalı ilə $y = kx + b$ formasında ifadə olunan, xəttin yamacını və ordinat kəsişməsini müəyyən edən tənlikdir.
#
#
#
# ---
#
# ## 📌 2. Düstur (2D müstəvi üçün)
#
# Əgər $\alpha$ — düz xəttin $x$ oxu ilə əmələ gətirdiyi bucaqdır, və $(x_0, y_0)$ xəttin üzərində bir nöqtədirsə, bucaq əmsallı tənlik belədir:
#
# $$
# y - y_0 = \tan \alpha \cdot (x - x_0)
# $$
#
# Burada:
#
# * $\tan \alpha = m$ — xəttin **meyl əmsalı**,
# * $(x_0, y_0)$ — xəttin üzərindəki nöqtə.
#
# Beləliklə, **sadələşdirilmiş formada**:
#
# $$
# y = m x + q
# $$
#
# * $m = \tan \alpha$ — meyl əmsalı,
# * $q = y_0 - m x_0$ — xəttin $y$ oxunu kəsdiyi nöqtə.
#
# ---
#
# ## 📌 3. Nümunə
#
# Xətt $(1, 2)$ nöqtəsindən keçir və $x$ oxu ilə $45^\circ$ bucaq əmələ gətirirsə:
#
# $$
# \tan 45^\circ = 1 \implies y - 2 = 1 \cdot (x - 1) \implies y = x + 1
# $$

# %% [markdown]
# ## Düz Xəttin Bucaq Əmsallı Tənliyi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_bucaq_emsalli_tenliyi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Düz Xəttin Bucaq Əmsallı Tənliyi', size=20)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Düz Xəttin Bucaq Əmsallı Tənliyi Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_bucaq_emsalli_tenliyi_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Düz Xəttin Bucaq Əmsallı Tənliyi
        
        Məsələ 1: M_0 (1;-2) nöqtəsindən keçən və Absis oxunun müsbət istiqaməti ilə 45 dərəcəlik
        bucaq əməmlə gətirən Düz Xəttin Bucaq Əmsallı Tənliyini yazın. """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Düz Xəttin Polyar koordinat sistemində Tənliyi

# %% [markdown]
# ## 📌 1. Tərif
#
# Poylar koordinat sistemində düz xətt, **qütb nöqtəsindən (O)** xəttə qədər olan **ən qısa məsafə** ($\rho$) və həmin məsafənin **Ox oxu ilə əmələ gətirdiyi bucaq** ($\varphi$) vasitəsilə ifadə olunur.
#
# Yəni hər düz xətt **$(\rho, \varphi)$** parametrləri ilə tam müəyyən edilir.
#
# ---
#
# ## 📌 2. Düstur
#
# Düz xəttin polyar koordinatlarda tənliyi belədir:
#
# $$
# x \cos \varphi + y \sin \varphi = \rho
# $$
#
# Burada:
#
# * $\rho$ — qütbdən (O) düz xəttə olan məsafə,
# * $\varphi$ — həmin məsafənin $Ox$ oxu ilə bucağı,
# * $(x, y)$ — düz xətt üzərindəki nöqtənin koordinatları.
#
# ---
#
# ## 📌 3. Poylar koordinatlara keçid
#
# Əgər nöqtə polyar sistemdə $(r, \theta)$ ilə verilibsə, onda:
#
# $$
# x = r \cos \theta, \quad y = r \sin \theta
# $$
#
# Bunları xətt tənliyinə qoysaq:
#
# $$
# r \cos(\theta - \varphi) = \rho
# $$
#
# Bu da **poylar formada düz xətt tənliyi**dir.
#
# ---
#
# ## 📌 4. Nümunə
#
# Məsələn, qütbdən məsafəsi $\rho = 5$, istiqamət bucağı $\varphi = 30^\circ$ olan düz xəttin tənliyi:
#
# $$
# x \cos 30^\circ + y \sin 30^\circ = 5
# $$
#
# $$
# \frac{\sqrt{3}}{2}x + \frac{1}{2}y = 5
# $$

# %% [markdown]
# ## Düz Xəttin Polyar koordinat sistemində Tənliyi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_polyar_koord_sis_tenliyi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 3):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Düz Xəttin Polyar koordinat sistemində Tənliyi', size=16)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Düz Xəttin Polyar koordinat sistemində Tənliyi Məsələləri

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_pol_koor_sis_tenliyi_mesele_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
        plt.imshow(image)
        
        plt.title("""  Düz Polyar koordinat sistemində Tənliyi
        
        Məsələ 1: A(2; pi/3) nöqtəsindən keçən və Polyar Oxla alfa = pi/6 bucağı əmələ gətirən 
        Düz Xəttin Polyar Koordinat Sistemində Tənliyini yazın. """)
        
        plt.axis('off')  # Oxları gizlətmək üçün
        plt.show()

# %% [markdown]
# ## Düz Xəttin Normal Tənliyi

# %% [markdown]
# ## 📌 1. Tərif
#
# **Normal tənlik** – düz xəttin qütbdən (başlanğıc nöqtədən $O$) xəttə qədər çəkilmiş **perpendikulyar (normal) məsafə** $\rho$ və həmin normalın **Ox oxu ilə əmələ gətirdiyi bucaq** $\varphi$ vasitəsilə yazılan tənlikdir.
#
# Başqa sözlə, xətt üzərindəki bütün nöqtələr $(x,y)$, bu **normal məsafə** və **bucaq** əsasında ifadə olunur.
#
# ---
#
# ## 📌 2. Düstur
#
# $$
# x \cos \varphi + y \sin \varphi = \rho
# $$
#
# Burada:
#
# * $\rho$ — qütbdən düz xəttə qədər məsafə,
# * $\varphi$ — normalın $Ox$ oxu ilə bucağı,
# * $(x, y)$ — düz xətt üzərindəki nöqtə.
#
# ---
#
# ## 📌 3. Ümumi tənliklə əlaqə
#
# Əgər xəttin ümumi tənliyi belədirsə:
#
# $$
# Ax + By + C = 0
# $$
#
# onda onu normal tənliyə gətirmək üçün əmsalları **normallaşdırmaq** lazımdır:
#
# $$
# \frac{A}{\sqrt{A^2+B^2}} \, x + \frac{B}{\sqrt{A^2+B^2}} \, y + \frac{C}{\sqrt{A^2+B^2}} = 0
# $$
#
# və burada:
#
# $$
# \rho = -\frac{C}{\sqrt{A^2+B^2}}, \quad
# \cos \varphi = \frac{A}{\sqrt{A^2+B^2}}, \quad
# \sin \varphi = \frac{B}{\sqrt{A^2+B^2}}
# $$
#
# ---
#
# ## 📌 4. Nümunə
#
# Düz xəttin ümumi tənliyi:
#
# $$
# 3x + 4y - 12 = 0
# $$
#
# * Normalın uzunluğu:
#
# $$
# \rho = \frac{| -12 |}{\sqrt{3^2+4^2}} = \frac{12}{5} = 2.4
# $$
#
# * Normal vektor: $(3,4)$, deməli:
#
# $$
# \cos \varphi = \tfrac{3}{5}, \quad \sin \varphi = \tfrac{4}{5}
# $$
#
# Normal tənlik:
#
# $$
# x \cdot \frac{3}{5} + y \cdot \frac{4}{5} = 2.4
# $$

# %% [markdown]
# ## Düz Xəttin Normal Tənliyi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_normal_tenliyi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Düz Xəttin Normal Tənliyi', size=16)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Düz Xəttin Vektorial Tənliyi

# %% [markdown]
# ## 📌 1. Tərif
#
# Düz xəttin **vektorial tənliyi** — düz xətt üzərindəki bütün nöqtələrin radius-vektorunu, başlanğıc nöqtənin radius-vektoru ilə istiqamət vektorunun xətti kombinasiyası şəklində ifadə edən tənlikdir.
#
# ---
#
# ## 📌 2. Düstur (2D və 3D üçün ümumi)
#
# Əgər düz xətt
#
# * $A(x_0, y_0, z_0)$ nöqtəsindən keçir (2D-də $z_0$ yoxdur),
# * istiqamət vektoru $\vec{v} = (a, b, c)$-dirsə,
#
# onda vektorial tənlik:
#
# $$
# \vec{r} = \vec{r_0} + t \vec{v}, \quad t \in \mathbb{R}
# $$
#
# Burada:
#
# * $\vec{r} = (x, y, z)$ — düz xətt üzərində istənilən nöqtənin radius-vektoru,
# * $\vec{r_0} = (x_0, y_0, z_0)$ — xəttin keçdiyi nöqtənin radius-vektoru,
# * $\vec{v} = (a, b, c)$ — istiqamət vektoru,
# * $t$ — parametr.
#
# ---
#
# ## 📌 3. 2D halda
#
# $$
# \vec{r} = (x, y), \quad \vec{r_0} = (x_0, y_0), \quad \vec{v} = (a, b)
# $$
#
# $$
# (x, y) = (x_0, y_0) + t (a, b)
# $$
#
# Bu da komponentlərdə:
#
# $$
# \begin{cases}
# x = x_0 + at \\
# y = y_0 + bt
# \end{cases}
# $$
#
# Yəni vektorial tənlik → parametrik tənliyin qısa yazılışıdır.
#
# ---
#
# ## 📌 4. Nümunə
#
# Xətt $A(1,2)$ nöqtəsindən keçir və istiqamət vektoru $\vec{v} = (3,4)$-dür.
#
# **Vektorial tənlik:**
#
# $$
# (x, y) = (1,2) + t(3,4), \quad t \in \mathbb{R}
# $$
#
# **Parametrik forması:**
#
# $$
# \begin{cases}
# x = 1 + 3t \\
# y = 2 + 4t
# \end{cases}
# $$

# %% [markdown]
# ## Düz Xəttin Vektorial Tənliyi

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Advanced_Mathematics\Pictures\Duz_xett_vektorial_tenliyi_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 2):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Düz Xəttin Vektorial Tənliyi', size=16)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
